# %% [markdown]
# # Result description

# %% [markdown]
# ## Test with 2 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from experiments import trainning_parametors
t_parametors = trainning_parametors.functions_train_parametors()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset TwoD_V1_0
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_0()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 199 1301]]
# ROC AUC : 0.43366666666666664
# Specificity : 0.0
# Precision : 0.9886018237082067
# Recall : 0.8673333333333333
# f1_score : 0.9240056818181819
# False alarm rate (%) : 13.266666666666671
# CPU Time (s) : 2.637188196182251
# Memory Consumption (o) : 11669504
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 2     0.203131  6.482506  0.612702   9.753596 -1
# 5     3.106334  6.076085  0.607694   9.917015 -1
# 19    5.589001  4.085129  0.607366   9.927750 -1
# 27    0.455350  6.459653  0.610236   9.833893 -1
# 33   -0.541941 -6.542501  0.626764   9.301813 -1
# 48   -5.926924 -3.395528  0.606278   9.963442 -1
# 53   -0.655484 -6.735926  0.666202   8.086826 -1
# 66   -6.188859  3.038016  0.608900   9.877512 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V1_1
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_1()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 163 1337]]
# ROC AUC : 0.44566666666666666
# Specificity : 0.0
# Precision : 0.988905325443787
# Recall : 0.8913333333333333
# f1_score : 0.9375876577840112
# False alarm rate (%) : 10.866666666666669
# CPU Time (s) : 2.797024965286255
# Memory Consumption (o) : 7061504
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 7    -6.702078 -0.822866  0.645581   8.712831 -1
# 9     4.636843 -5.025406  0.601026  10.136693 -1
# 14    0.836414 -6.300447  0.620337   9.507020 -1
# 15    6.600900  1.560175  0.669396   7.991589 -1
# 22    6.822442  0.324249  0.701930   7.046692 -1
# 26   -2.846081 -6.269712  0.615713   9.655992 -1
# 59    0.271346  6.840972  0.673030   7.883786 -1
# 65    5.413343  3.938120  0.604092  10.035368 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V2
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V2()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 165 1335]]
# ROC AUC : 0.445
# Specificity : 0.0
# Precision : 0.9888888888888889
# Recall : 0.89
# f1_score : 0.9368421052631579
# False alarm rate (%) : 10.999999999999998
# CPU Time (s) : 2.611999034881592
# Memory Consumption (o) : 1961984
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 9    -1.347989  6.713981  0.643755   8.769227 -1
# 13    2.234380 -6.543622  0.606448   9.957880 -1
# 18   -6.667471  0.034495  0.628964   9.232028 -1
# 23    2.606104 -6.436010  0.606531   9.955157 -1
# 26    2.358630  6.514871  0.627047   9.292820 -1
# 44   -6.430212  1.043792  0.605045  10.003972 -1
# 45   -6.462990 -0.951489  0.600098  10.167433 -1
# 50   -1.824710  6.495816  0.601438  10.123048 -1
# 52    4.930923  4.914162  0.601845  10.109571 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V3_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_0_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 120 1380]]
# ROC AUC : 0.46
# Specificity : 0.0
# Precision : 0.989247311827957
# Recall : 0.92
# f1_score : 0.9533678756476685
# False alarm rate (%) : 7.9999999999999964
# CPU Time (s) : 2.5986328125
# Memory Consumption (o) : 5013504
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 19   -2.668775 -8.494902  0.601583  10.118231 -1
# 59   -8.500154 -1.780681  0.608106   9.903509 -1
# 73   -2.624391  8.580181  0.621450   9.471342 -1
# 100   3.189854  8.332516  0.600193  10.164291 -1
# 103   0.201188  8.765202  0.622054   9.451988 -1
# 107   3.509355  8.259046  0.600307  10.160518 -1
# 112  -2.064159 -8.710929  0.626878   9.298179 -1
# 114  -8.827491  0.918381  0.653825   8.460184 -1
# 146   1.104677 -8.578383  0.617785   9.589091 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V3_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_1_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  10    5]
#  [ 123 1377]]
# ROC AUC : 0.7923333333333334
# Specificity : 0.6666666666666666
# Precision : 0.9963820549927641
# Recall : 0.918
# f1_score : 0.9555863983344899
# False alarm rate (%) : 8.199999999999996
# CPU Time (s) : 3.0894670486450195
# Memory Consumption (o) : 3289088
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 2    -8.515358 -2.442636  0.618618   9.562277 -1
# 3     8.804022  0.685126  0.644697   8.740110 -1
# 4     0.956723 -8.566267  0.610868   9.813282 -1
# 25   -8.695676  1.661084  0.631265   9.159336 -1
# 31   -8.937368  0.562304  0.665017   8.122278 -1
# 43   -2.888530  8.300139  0.604716  10.014816 -1
# 56    8.844902 -1.301756  0.658433   8.320374 -1
# 64    1.844177 -8.510702  0.601368  10.125365 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V3_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_2_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 149 1351]]
# ROC AUC : 0.4503333333333333
# Specificity : 0.0
# Precision : 0.9890190336749634
# Recall : 0.9006666666666666
# f1_score : 0.9427773900907187
# False alarm rate (%) : 9.933333333333339
# CPU Time (s) : 2.601746082305908
# Memory Consumption (o) : 2048000
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 34    8.723502 -2.203662  0.652616   8.497051 -1
# 35    8.469724 -1.092604  0.609524   9.857125 -1
# 36   -1.659311  8.591255  0.637044   8.977899 -1
# 45   -0.463911  8.802505  0.674470   7.841245 -1
# 61   -8.740915 -1.751509  0.633959   9.074536 -1
# 64   -3.097710  8.269712  0.604935  10.007612 -1
# 71    7.959380 -4.041950  0.602613  10.084186 -1
# 75   -8.839188 -1.067730  0.639040   8.915592 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V3_3_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_3_0()
x_lim = 13
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  95 1405]]
# ROC AUC : 0.4683333333333333
# Specificity : 0.0
# Precision : 0.9894366197183099
# Recall : 0.9366666666666666
# f1_score : 0.9623287671232876
# False alarm rate (%) : 6.333333333333336
# CPU Time (s) : 2.538243293762207
# Memory Consumption (o) : 1114112
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 13   -8.861757  1.069600  0.613798   9.717998 -1
# 27    1.087052 -8.822099  0.623139   9.417300 -1
# 39   -2.071597  8.576814  0.603460  10.056213 -1
# 49   -0.491496 -8.795286  0.609304   9.864328 -1
# 58    8.772298  0.535760  0.602696  10.081430 -1
# 80   -8.693456  2.151312  0.614019   9.710843 -1
# 88   -8.879958  0.203795  0.609402   9.861116 -1
# 96    0.164314  8.826885  0.629187   9.224976 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V3_4_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_4_0()
x_lim = 17
y_lim = 12
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   6    9]
#  [ 122 1378]]
# ROC AUC : 0.6593333333333333
# Specificity : 0.4
# Precision : 0.9935111751982696
# Recall : 0.9186666666666666
# f1_score : 0.9546241773467267
# False alarm rate (%) : 8.133333333333336
# CPU Time (s) : 2.77937388420105
# Memory Consumption (o) : 4206592
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 33   -2.569256 -9.459778  0.610503   9.825183 -1
# 47    1.964131 -9.638405  0.642039   8.822370 -1
# 53   -9.576551 -2.030693  0.616437   9.632592 -1
# 67   -9.717422 -0.983639  0.627179   9.288622 -1
# 72   -9.405004 -2.528067  0.601430  10.123312 -1
# 74    0.638235  9.743973  0.618000   9.582173 -1
# 78   -9.284374 -3.456329  0.602261  10.095804 -1
# 80    9.450792  2.641155  0.611878   9.780402 -1
# ...

# %% [markdown]
# ### Dataset 4.2.0
# #### Conclusion on this dataset :
# EIF is better than IForest

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V4_2_0()
x_lim = 17
y_lim = 12
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  12    3]
#  [ 103 1397]]
# ROC AUC : 0.8656666666666668
# Specificity : 0.8
# Precision : 0.9978571428571429
# Recall : 0.9313333333333333
# f1_score : 0.963448275862069
# False alarm rate (%) : 6.866666666666665
# CPU Time (s) : 2.7290050983428955
# Memory Consumption (o) : 2019328
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 14   -9.833627  1.197827  0.622760   9.429418 -1
# 30    9.828632 -0.031127  0.637745   8.956002 -1
# 50    9.770576  0.818329  0.608700   9.884083 -1
# 55   -9.753306 -1.473940  0.602370  10.092203 -1
# 57    0.734276 -9.830159  0.636458   8.996208 -1
# 63   -1.499269  9.885414  0.622482   9.438295 -1
# 69    9.955211  0.067153  0.668109   8.029913 -1
# 75   -9.799659  0.984891  0.611542   9.791340 -1
# ...

# %% [markdown]
# ### Dataset 4.3.0
# #### Conclusion on this dataset :
# EIF is better than IForest

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V4_3_0()
x_lim = 23
y_lim = 16
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [ 127 1373]]
# ROC AUC : 0.9576666666666667
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.9153333333333333
# f1_score : 0.9557953358858337
# False alarm rate (%) : 8.466666666666667
# CPU Time (s) : 2.657945156097412
# Memory Consumption (o) : 798720
# ****************************************************************
# Abnormal predicted data by IForest
#               0          1         2          3  4
# 14    15.777247  -2.601406  0.631185   9.161838 -1
# 15    10.601558  11.259667  0.600215  10.163563 -1
# 18    11.042708  10.759216  0.607074   9.937331 -1
# 19    15.648562  -2.155998  0.606765   9.947477 -1
# 24    11.594480  10.548378  0.607147   9.934928 -1
# 28   -15.741548  -1.482558  0.618695   9.559799 -1
# 34    15.926784  -0.067110  0.655479   8.409889 -1
# 66    12.212051  10.145928  0.603947  10.040140 -1
# ...

# %% [markdown]
# ### Dataset 4.3.1
# #### Conclusion on this dataset :
# EIF is better than IForest

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V4_3_1()
x_lim = 29
y_lim = 20
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  12    3]
#  [ 105 1395]]
# ROC AUC : 0.8650000000000001
# Specificity : 0.8
# Precision : 0.9978540772532188
# Recall : 0.93
# f1_score : 0.9627329192546584
# False alarm rate (%) : 6.999999999999995
# CPU Time (s) : 2.368323802947998
# Memory Consumption (o) : 1142784
# ****************************************************************
# Abnormal predicted data by IForest
#               0          1         2          3  4
# 3     -1.921104 -17.782713  0.621254   9.477619 -1
# 6      4.068804 -17.448315  0.605142  10.000789 -1
# 29    17.800596  -1.615790  0.622749   9.429756 -1
# 56   -17.726970  -0.383757  0.613433   9.729851 -1
# 65   -17.858810   1.394127  0.647876   8.642174 -1
# 87    17.668526   0.949484  0.600817  10.143611 -1
# 90     3.170533 -17.684995  0.621853   9.458432 -1
# 91    -0.677644  17.924996  0.656838   8.368661 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V5_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_0_0()
x_lim = 30
y_lim = 20
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  69 1431]]
# ROC AUC : 0.977
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.954
# f1_score : 0.9764585465711361
# False alarm rate (%) : 4.600000000000004
# CPU Time (s) : 2.4222068786621094
# Memory Consumption (o) : 241664
# ****************************************************************
# Abnormal predicted data by IForest
#               0         1         2          3  4
# 48    -9.756232 -0.314399  0.600072  10.168305 -1
# 56    -0.713128  9.939985  0.643626   8.773233 -1
# 70     0.892557  9.778815  0.617960   9.583468 -1
# 76     1.819105 -9.796086  0.624101   9.386577 -1
# 78    -1.623038 -9.738521  0.615874   9.650784 -1
# 88     0.449610  9.778407  0.610982   9.809570 -1
# 107   -9.824901 -0.577122  0.620692   9.495631 -1
# 114   -0.287528  9.947739  0.644788   8.737306 -1
# 227   -9.745974 -2.114955  0.606701   9.949567 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V5_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_1_0()
x_lim = 40
y_lim = 30
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  85 1415]]
# ROC AUC : 0.9716666666666667
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.9433333333333334
# f1_score : 0.9708404802744426
# False alarm rate (%) : 5.666666666666664
# CPU Time (s) : 2.67939829826355
# Memory Consumption (o) : -7020544
# ****************************************************************
# Abnormal predicted data by IForest
#               0         1         2          3  4
# 0     -9.950855  0.830797  0.650930   8.548559 -1
# 10    -1.894561  9.775693  0.648740   8.615661 -1
# 16    -9.799835  1.895527  0.602438  10.089957 -1
# 27     1.210838  9.831302  0.659948   8.274599 -1
# 66    -1.727424  9.652656  0.632159   9.131154 -1
# 75    -9.684534 -2.362096  0.601268  10.128648 -1
# 95     3.185275  9.381740  0.600083  10.167934 -1
# 101   -0.094694  9.780700  0.645411   8.718071 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V6_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_0_0()
x_lim = 30
y_lim = 20
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  67 1433]]
# ROC AUC : 0.9776666666666667
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.9553333333333334
# f1_score : 0.9771564950562565
# False alarm rate (%) : 4.466666666666663
# CPU Time (s) : 2.7238051891326904
# Memory Consumption (o) : 69632
# ****************************************************************
# Abnormal predicted data by IForest
#               0          1         2          3  4
# 13     0.817795   9.963613  0.641012   8.854258 -1
# 37    -9.979513   0.010553  0.652706   8.494289 -1
# 60     9.952496  -0.636267  0.622581   9.435136 -1
# 83    -9.860956  -1.439532  0.635862   9.014866 -1
# 94     0.624635   9.756730  0.602874  10.075549 -1
# 101   -0.949394  -9.857108  0.629745   9.207322 -1
# 110   -9.853570  -0.145434  0.631701   9.145588 -1
# 115    1.381558  -9.706834  0.627142   9.289789 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V6_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_1_0()
x_lim = 40
y_lim = 30
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, show_samples=True)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  51 1449]]
# ROC AUC : 0.983
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.966
# f1_score : 0.982706002034588
# False alarm rate (%) : 3.400000000000003
# CPU Time (s) : 2.234412908554077
# Memory Consumption (o) : 3887104
# ****************************************************************
# Abnormal predicted data by IForest
#               0          1         2          3  4
# 33    -9.941839  -0.288680  0.649111   8.604272 -1
# 72     0.676906  -9.894116  0.618171   9.576652 -1
# 97     9.816454  -1.205796  0.607338   9.928655 -1
# 137    0.499059   9.925171  0.618029   9.581240 -1
# 142   -9.883271   1.197120  0.634047   9.071781 -1
# 172    0.284540  -9.961900  0.648048   8.636903 -1
# 202    0.434915  -9.940471  0.644210   8.755165 -1
# 275   -0.686255   9.874156  0.604316  10.027970 -1
# 297    1.534749  -9.866153  0.606167   9.967098 -1
# ...
