# %% [markdown]
# # Differents Formulars For Threshold

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from metrics import threshold_evaluator
t_evaluator = threshold_evaluator.functions_threshold_evaluator()

# %% [markdown]
# ## Generals settings

# %%
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5
formularBasedOn = ["PathLength", "Scores", "MajorityVoting"]

# %% [markdown]
# ## 1 Dimension
# Majority Voting est plus rapide, fais moins de fausses alertes mais donne à peu près la même spécifité que basé sur le scores.

# %%
X_brut, y_transform, full_dataset = dts.OneD_V2()
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[0])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
# Out:
# ########################################PathLength########################################
# ---------------------------------N°0----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°1----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°2----------------------------------------------------
# ...

# %% [markdown]
# ## 2 Dimensions

# %%
X_brut, y_transform, full_dataset = dts.TwoD_V4_2_0()
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[0])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
# Out:
# ########################################PathLength########################################
# ---------------------------------N°0----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°1----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°2----------------------------------------------------
# ...

# %% [markdown]
# ## 3 Dimensions

# %%
X_brut, y_transform, full_dataset = dts.ThreeD_V4_2_0()
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[0])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
# Out:
# ########################################PathLength########################################
# ---------------------------------N°0----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°1----------------------------------------------------
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : None
# Memory Consumption (o) : None
# ****************************************************************
# ---------------------------------N°2----------------------------------------------------
# ...
