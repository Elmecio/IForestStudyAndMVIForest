# %% [markdown]
# # Majority Voting IForest study

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from metrics import threshold_evaluator, useful_infos
t_evaluator = threshold_evaluator.functions_threshold_evaluator()

formularBasedOn = useful_infos._ANOMALY_DETECTION_MODELS

# %% [markdown]
# ## Generals settings

# %%
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %%
def far():
    far = 0.0
    for i in range(0, len(fn), 1):
        far = far + (fn[i] * 100)/(fn[i]+tn[i])
    print("far moyen = "+str(far/len(fn)))
    return far/len(fn)

# %% [markdown]
# ## Test with publics datasets

# %%
publics_dts = datat.reals_datasets(path_top="../../../../../")

# %% [markdown]
# ### Dataset Shuttle_IForestASD
# #### Conclusion on this dataset :

# %%
max_samples = 1024
X_brut, y_transform, full_dataset = publics_dts.Shuttle_IForestASD()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=1024########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 1024
# ########################################Original EIFwith max_samples=1024########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7850c1c4701c> in <module>
#      10                                        y_transform=y_transform, basedOn=formularBasedOn[3])
#      11 t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold,
# ---> 12                                        y_transform=y_transform, basedOn=formularBasedOn[4])
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in execute_iforest_for_seaching_threshold(self, X_brut, max_samples, n_trees, number, y_transform, basedOn, different_subsample)
#     301             elif basedOn == "Original EIF":
#     302                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_eif(
# --> 303                     X_brut, max_samples, n_trees, number)
#     304             elif basedOn == "Local Original EIF":
#     305                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_local_eif(
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in simple_execute_eif(self, X_brut, max_samples, n_trees, threshold)
#     132
#     133         F1, P1, S1, pathsLength, X_normal, X_abnormal, result_dataset, exec_time, exec_memory  = func.execute_EIF(
# --> 134             X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold)
#     135
#     136         exec_time = time() - start_time
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/functions.py in execute_EIF(self, X_brut, X_train, max_samples, n_trees, threshold)
#     129
#     130         if X_train is None:
# --> 131             F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=1)
#     132         else:
#     133             print("X_Train is not None")
#
# _eif.pyx in eif.iForest.__cinit__()
#
# ValueError: Buffer dtype mismatch, expected 'double' but got 'long'

# %%
#Shuttle
#MVIForest
tn = [3449,3443,3447,3457,3437]
fn = [1057,957,1165,1283,917]
print("MVIFOrest mean far = "+str(far()))
#IForest
tn = [3455,3462,3477,3468,3462]
fn = [1171,1095,1701,1529,1314]
print("IForest mean far = "+str(far()))
# Out:
# far moyen = 23.71928133509899
# MVIFOrest mean far = 23.71928133509899
# far moyen = 28.060771086613777
# IForest mean far = 28.060771086613777

# %% [markdown]
# ### Dataset SMTP_IForestASD
# #### Conclusion on this dataset :

# %%
max_samples = 1024
X_brut, y_transform, full_dataset = publics_dts.SMTP_IForestASD()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=1024########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 1024
# ########################################Original EIFwith max_samples=1024########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9d26d3f16942> in <module>
#      10                                        y_transform=y_transform, basedOn=formularBasedOn[3])
#      11 t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold,
# ---> 12                                        y_transform=y_transform, basedOn=formularBasedOn[4])
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in execute_iforest_for_seaching_threshold(self, X_brut, max_samples, n_trees, number, y_transform, basedOn, different_subsample)
#     301             elif basedOn == "Original EIF":
#     302                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_eif(
# --> 303                     X_brut, max_samples, n_trees, number)
#     304             elif basedOn == "Local Original EIF":
#     305                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_local_eif(
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in simple_execute_eif(self, X_brut, max_samples, n_trees, threshold)
#     132
#     133         F1, P1, S1, pathsLength, X_normal, X_abnormal, result_dataset, exec_time, exec_memory  = func.execute_EIF(
# --> 134             X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold)
#     135
#     136         exec_time = time() - start_time
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/functions.py in execute_EIF(self, X_brut, X_train, max_samples, n_trees, threshold)
#     129
#     130         if X_train is None:
# --> 131             F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=1)
#     132         else:
#     133             print("X_Train is not None")
#
# _eif.pyx in eif.iForest.__cinit__()
#
# ValueError: Buffer dtype mismatch, expected 'double' but got 'long'

# %%
#SMTP
#MVIForest
tn = [23,23,22,23,22]
fn = [7188,6663,7814,7753,7709]
print("MVIFOrest mean far = "+str(far()))
#IForest
tn = [22,22,23,22,22]
fn = [6364,6484,7706,7287,6573]
print("IForest mean far = "+str(far()))
# Out:
# far moyen = 99.69518689155991
# MVIFOrest mean far = 99.69518689155991
# far moyen = 99.67703632766369
# IForest mean far = 99.67703632766369

# %% [markdown]
# ### Dataset ForestCover_IForestASD
# #### Conclusion on this dataset :

# %%
max_samples = 2048
X_brut, y_transform, full_dataset = publics_dts.ForestCover_IForestASD()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=2048########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 2048
# ########################################Original EIFwith max_samples=2048########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a62d1d535b6e> in <module>
#      10                                        y_transform=y_transform, basedOn=formularBasedOn[3])
#      11 t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold,
# ---> 12                                        y_transform=y_transform, basedOn=formularBasedOn[4])
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in execute_iforest_for_seaching_threshold(self, X_brut, max_samples, n_trees, number, y_transform, basedOn, different_subsample)
#     301             elif basedOn == "Original EIF":
#     302                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_eif(
# --> 303                     X_brut, max_samples, n_trees, number)
#     304             elif basedOn == "Local Original EIF":
#     305                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_local_eif(
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in simple_execute_eif(self, X_brut, max_samples, n_trees, threshold)
#     132
#     133         F1, P1, S1, pathsLength, X_normal, X_abnormal, result_dataset, exec_time, exec_memory  = func.execute_EIF(
# --> 134             X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold)
#     135
#     136         exec_time = time() - start_time
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/functions.py in execute_EIF(self, X_brut, X_train, max_samples, n_trees, threshold)
#     129
#     130         if X_train is None:
# --> 131             F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=1)
#     132         else:
#     133             print("X_Train is not None")
#
# _eif.pyx in eif.iForest.__cinit__()
#
# ValueError: Buffer dtype mismatch, expected 'double' but got 'long'

# %%
#ForestCover
#MVIForest
tn = [2297,1652,1951,1808,1894]
fn = [28189,24953,30753,29417,25756]
print("MVIFOrest mean far = "+str(far()))
#IForest
tn = [2491,2503,2286,2621,2050]
fn = [46018,47202,41288,39194,46369]
print("IForest mean far = "+str(far()))
# Out:
# far moyen = 93.53005238460169
# MVIFOrest mean far = 93.53005238460169
# far moyen = 94.8161902468049
# IForest mean far = 94.8161902468049

# %% [markdown]
# ### Dataset HTTP_IForestASD
# #### Conclusion on this dataset :

# %%
max_samples = 4096
X_brut, y_transform, full_dataset = publics_dts.HTTP_IForestASD()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=4096########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 4096
# ########################################Original EIFwith max_samples=4096########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-61e64834d7c1> in <module>
#      10                                        y_transform=y_transform, basedOn=formularBasedOn[3])
#      11 t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold,
# ---> 12                                        y_transform=y_transform, basedOn=formularBasedOn[4])
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in execute_iforest_for_seaching_threshold(self, X_brut, max_samples, n_trees, number, y_transform, basedOn, different_subsample)
#     301             elif basedOn == "Original EIF":
#     302                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_eif(
# --> 303                     X_brut, max_samples, n_trees, number)
#     304             elif basedOn == "Local Original EIF":
#     305                 IFD_y_pred_IF, IFD_scores, using_threshold, exec_time, exec_memory  = self.simple_execute_local_eif(
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/threshold_evaluator.py in simple_execute_eif(self, X_brut, max_samples, n_trees, threshold)
#     132
#     133         F1, P1, S1, pathsLength, X_normal, X_abnormal, result_dataset, exec_time, exec_memory  = func.execute_EIF(
# --> 134             X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold)
#     135
#     136         exec_time = time() - start_time
#
# ~/Documents/Devs/AnacondaSpaceNew/OD_Jupyter/metrics/functions.py in execute_EIF(self, X_brut, X_train, max_samples, n_trees, threshold)
#     129
#     130         if X_train is None:
# --> 131             F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=1)
#     132         else:
#     133             print("X_Train is not None")
#
# _eif.pyx in eif.iForest.__cinit__()
#
# ValueError: Buffer dtype mismatch, expected 'double' but got 'long'

# %%
#HTTP
#MVIForest
tn = [2209,2211,2211,2211,2211]
fn = [11873,13792,10095,11249,14401]
print("MVIFOrest mean far = "+str(far()))
#IForest
tn = [2211,2211,2211,2211,2211]
fn = [16509,12195,14516,13325,12179]
print("IForest mean far = "+str(far()))
# Out:
# far moyen = 84.55883968996746
# MVIFOrest mean far = 84.55883968996746
# far moyen = 86.00537628087477
# IForest mean far = 86.00537628087477

# %% [markdown]
# ### Dataset Shuttle_Goldein
# #### Conclusion on this dataset :

# %%
max_samples = 1024
X_brut, y_transform, full_dataset = publics_dts.Shuttle_Goldein()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=1024########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 1024
# ########################################Original EIFwith max_samples=1024########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original EIF with max_samples= 1024
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# ### Dataset KDD99_Goldein
# #### Conclusion on this dataset :
# - MVIForest et IForest sont pareils alors varier la taille de l'échantillon pour voir si à partir d'un moment donné, MVIForest fait mieux que IForest.
# - Cela conforterait dans l'hypothèse où la taille de l'échantillon a un grad impact sur la performance de IForest.

# %%
max_samples = 4096
X_brut, y_transform, full_dataset = publics_dts.KDD99_Goldein()
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[0])
#t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=1, 
#                                       y_transform=y_transform, basedOn=formularBasedOn[1])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[2])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[3])
t_evaluator.execute_iforest_for_seaching_threshold(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, number=threshold, 
                                       y_transform=y_transform, basedOn=formularBasedOn[4])
# Out:
# ########################################MajorityVotingwith max_samples=4096########################################
# Majority Voting Prediction And Number of Trees Needed
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original IForest with max_samples= 4096
# ########################################Original EIFwith max_samples=4096########################################
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Result of IForest based on Original EIF with max_samples= 4096
# /home/momo/anaconda3/lib/python3.7/site-packages/matplotlib/text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
