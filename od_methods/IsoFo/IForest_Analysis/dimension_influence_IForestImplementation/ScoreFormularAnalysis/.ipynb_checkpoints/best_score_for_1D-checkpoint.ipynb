# %% [markdown]
# # Result description

# %% [markdown]
# ## Test with 1 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat

from metrics import threshold_evaluator
t_evaluator = threshold_evaluator.functions_threshold_evaluator()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset OneD_V1_0
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.OneD_V1_0()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_evaluator.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
#print("################################################## EIF ###################################")
#t_evaluator.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
#                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# ---------------------------------Threshold = 0.1----------------------------------------------------
# Confusion matrice
# [[  5   0]
#  [100   0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# False alarm rate (%) : 100.0
# ****************************************************************
# ---------------------------------Threshold = 0.2----------------------------------------------------
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion matrice
# [[  5   0]
#  [100   0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# ...

# %% [markdown]
# ### Dataset OneD_V1_1
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.OneD_V1_1()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_evaluator.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
#print("################################################## EIF ###################################")
#t_evaluator.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
#                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# ---------------------------------Threshold = 0.1----------------------------------------------------
# Confusion matrice
# [[  15    0]
#  [1500    0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# False alarm rate (%) : 100.0
# ****************************************************************
# ---------------------------------Threshold = 0.2----------------------------------------------------
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion matrice
# [[  15    0]
#  [1500    0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# ...

# %% [markdown]
# ### Dataset OneD_V2
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.OneD_V2()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_evaluator.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
#print("################################################## EIF ###################################")
#t_evaluator.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
#                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# ---------------------------------Threshold = 0.1----------------------------------------------------
# Confusion matrice
# [[  15    0]
#  [1500    0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# False alarm rate (%) : 100.0
# ****************************************************************
# ---------------------------------Threshold = 0.2----------------------------------------------------
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion matrice
# [[  15    0]
#  [1500    0]]
# ROC AUC : 0.5
# Specificity : 1.0
# Precision : 0.0
# Recall : 0.0
# f1_score : 0.0
# ...
