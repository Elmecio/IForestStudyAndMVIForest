# %% [markdown]
# # What is IForest behavior according to the dataset dimension size?

# %% [markdown]
# ## Test with 1 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
from IForest_DODiMDS import iforest_D as IFD
from metrics import performances
from metrics import visualization
visu = visualization.visualization()

import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score
from imblearn.metrics import specificity_score
from imblearn.metrics import sensitivity_score
from imblearn.metrics import specificity_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve

import matplotlib.cm as cm
from mpl_toolkits import mplot3d

# %% [markdown]
# ## Generals settings

# %%
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Chargement du jeu de données

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
X_brut, y_transform, full_dataset = dts.TwoD_V3_1_0()
X_brut.describe()
# Out:
# Columns number = 3
#                  0            1
# count  1516.000000  1516.000000
# mean     -0.046882    -0.148853
# std       4.283543     4.279187
# min      -6.943031    -6.951449
# 25%      -4.339136    -4.310212
# 50%       0.048253    -0.282864
# 75%       4.144797     3.966535
# max       6.930738     6.985053

# %%
dts.description
# Out:
# "Jeu de données à 2 dimensions constitué de données normales et 1% de données anormales. Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales. Ici, les données anormales sont plus éloignées des données normales mais et se ressemblent beaucoup. \n Données normales : Données aléatoire uniforme, X1 entre -5 et 5, X2 entre -7 et 7, size = 1500, distance euclidienne entre 5 et 7 (Grand cercle de rayon 7 et petit cercle de rayon 5) \n Données anormales : Données aléatoire gaussienne, mu = 0, sigma = 0.5, size = 15."

# %%
full_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516 entries, 0 to 1515
# Data columns (total 3 columns):
# 0    1516 non-null float64
# 1    1516 non-null float64
# 2    1516 non-null object
# dtypes: float64(2), object(1)
# memory usage: 35.7+ KB

# %%
X_brut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516 entries, 0 to 1515
# Data columns (total 2 columns):
# 0    1516 non-null float64
# 1    1516 non-null float64
# dtypes: float64(2)
# memory usage: 23.8 KB

# %%
y_transform.describe()
# Out:
#                  0
# count  1516.000000
# mean      0.980211
# std       0.198020
# min      -1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
y_transform
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 1511 -1
# 1512 -1
# 1513 -1
# 1514 -1
# 1515 -1
#
# [1516 rows x 1 columns]

# %% [markdown]
# ## Execution of Iforest to get the best performance

# %%
roc_aucs = []
specificities = []
for i in range(10):
    # Instanciation, fit and predict
    func_IFD = IFD.IsolationForest(sample_size = max_samples, n_trees=n_trees)
    func_IFD.fit(X_brut)
    IFD_y_pred_IF, IFD_scores = func_IFD.predict(X=X_brut, threshold=threshold)

    # Matrice de confusion
    ttn, tfp, tfn, ttp = confusion_matrix(y_transform, IFD_y_pred_IF).ravel()
    print(confusion_matrix(y_transform, IFD_y_pred_IF))
    #ROC AUC
    roc_aucs.append(roc_auc_score(y_transform, IFD_y_pred_IF))
    # Specificity
    specificities.append(specificity_score(y_transform, IFD_y_pred_IF))
print("ROC AUC")
print(roc_aucs)
print("Specificities")
print(specificities)
min_roc_auc = max(roc_aucs)
print("min_roc_auc = "+str(min_roc_auc))
# Out:
# [[   0   15]
#  [ 148 1353]]
# [[   0   15]
#  [ 144 1357]]
# [[   7    8]
#  [ 163 1338]]
# [[   0   15]
#  [ 124 1377]]
# [[   1   14]
#  [ 162 1339]]
# [[   0   15]
#  [ 136 1365]]
# [[   0   15]
#  [ 135 1366]]
# [[   0   15]
#  [ 136 1365]]
# [[   0   15]
#  [ 141 1360]]
# [[   5   10]
#  [ 163 1338]]
# ROC AUC
# [0.45069953364423715, 0.4520319786808794, 0.6790361980901621, 0.4586942038640906, 0.47936930934932265, 0.4546968687541639, 0.45502998001332445, 0.4546968687541639, 0.4530313124583611, 0.6123695314234956]
# Specificities
# [0.0, 0.0, 0.4666666666666667, 0.0, 0.06666666666666667, 0.0, 0.0, 0.0, 0.0, 0.3333333333333333]
# min_roc_auc = 0.6790361980901621

# %%
# Varier le seuil de décision pour voir l'impact
for i in np.arange(0.1, 1., 0.1):
    print("threshold = "+str(i))
    # Instanciation, fit and predict
    func_IFD = IFD.IsolationForest(sample_size = max_samples, n_trees=n_trees)
    func_IFD.fit(X_brut)
    IFD_y_pred_IF, IFD_scores = func_IFD.predict(X=X_brut, threshold=i)
    # Matrice de confusion
    #ttn, tfp, tfn, ttp = confusion_matrix(y_transform, IFD_y_pred_IF).ravel()
    print(confusion_matrix(y_transform, IFD_y_pred_IF))
# Out:
# threshold = 0.1
# [[  15    0]
#  [1501    0]]
# threshold = 0.2
# [[  15    0]
#  [1501    0]]
# threshold = 0.30000000000000004
# [[  15    0]
#  [1501    0]]
# threshold = 0.4
# [[  15    0]
#  [1501    0]]
# threshold = 0.5
# [[  15    0]
#  [1501    0]]
# threshold = 0.6
# [[   0   15]
#  [ 133 1368]]
# threshold = 0.7000000000000001
# [[   0   15]
#  [   0 1501]]
# threshold = 0.8
# [[   0   15]
#  [   0 1501]]
# threshold = 0.9
# [[   0   15]
#  [   0 1501]]

# %%
(119/(119+1382))*100
# Out:
# 7.928047968021319

# %% [markdown]
# ### Execution Of EIF on dataset

# %%
import eif
X_brut_numpy = X_brut.to_numpy()

# %%
F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=0)
S1 = F1.compute_paths(X_in=X_brut_numpy)
P1 = np.where(S1>=threshold,-1,1)

# Matrice de confusion
#ttn, tfp, tfn, ttp = confusion_matrix(y_transform_Shuttle, MS_y_pred_IF_Shuttle).ravel()
print(confusion_matrix(y_transform, P1))
# Out:
# [[   0   15]
#  [   0 1501]]

# %%
# Varier le seuil de décision pour voir l'impact
for i in np.arange(0.1, 1., 0.1):
    print("threshold = "+str(i))
    # Instanciation, fit and predict
    F1  = eif.iForest(X_brut_numpy, ntrees=n_trees, sample_size=max_samples, ExtensionLevel=0)
    S1 = F1.compute_paths(X_in=X_brut_numpy)
    P1 = np.where(S1>=i,-1,1)
    # Matrice de confusion
    #ttn, tfp, tfn, ttp = confusion_matrix(y_transform, IFD_y_pred_IF).ravel()
    print(confusion_matrix(y_transform, P1))
# Out:
# threshold = 0.1
# [[  15    0]
#  [1501    0]]
# threshold = 0.2
# [[  15    0]
#  [1501    0]]
# threshold = 0.30000000000000004
# [[  15    0]
#  [1501    0]]
# threshold = 0.4
# [[  15    0]
#  [1501    0]]
# threshold = 0.5
# [[  15    0]
#  [1033  468]]
# threshold = 0.6
# [[   0   15]
#  [   0 1501]]
# threshold = 0.7000000000000001
# [[   0   15]
#  [   0 1501]]
# threshold = 0.8
# [[   0   15]
#  [   0 1501]]
# threshold = 0.9
# [[   0   15]
#  [   0 1501]]

# %% [markdown]
# EIF ne détecte pas les anomalies. En fait, EIF considère toutes les données comme étant normales

# %%
roc_auc_IF = []
max_samples_IF = []
specificities = []

for j in range(min_sample_size, len(X_brut), sample_size_step):
    print("max_samples = "+str(j))
    max_samples = j
    # Instanciation, fit and predict
    func_IF = IFD.IsolationForest(sample_size = max_samples, n_trees=n_trees)
    func_IF.fit(X_brut)
    y_pred_IF, scores = func_IF.predict(X=X_brut, threshold=threshold)
    
    #Confusion matrix
    print(confusion_matrix(y_transform, y_pred_IF))
    
    # Specificity
    specificities.append(specificity_score(y_transform, y_pred_IF))

    auc_IF = roc_auc_score(y_transform, y_pred_IF)
    if auc_IF >= min_roc_auc:
        print("auc_IF = "+str(auc_IF))
        roc_auc_IF.append(auc_IF)
        max_samples_IF.append(j)
# Out:
# max_samples = 5
# [[  15    0]
#  [1501    0]]
# max_samples = 10
# [[  15    0]
#  [1501    0]]
# max_samples = 15
# [[  15    0]
#  [1501    0]]
# max_samples = 20
# [[  15    0]
#  [1501    0]]
# max_samples = 25
# [[  15    0]
#  [1501    0]]
# max_samples = 30
# [[  15    0]
#  [1501    0]]
# max_samples = 35
# [[  15    0]
#  [1501    0]]
# max_samples = 40
# [[  15    0]
#  [1501    0]]
# max_samples = 45
# [[  15    0]
#  [1501    0]]
# max_samples = 50
# [[  15    0]
#  [1501    0]]
# max_samples = 55
# [[  15    0]
#  [1501    0]]
# max_samples = 60
# [[  15    0]
#  [1501    0]]
# max_samples = 65
# [[  15    0]
#  [1501    0]]
# max_samples = 70
# [[  15    0]
#  [1501    0]]
# max_samples = 75
# [[  15    0]
#  [1501    0]]
# max_samples = 80
# [[  15    0]
#  [1501    0]]
# max_samples = 85
# [[  15    0]
#  [1501    0]]
# max_samples = 90
# [[  15    0]
#  [1501    0]]
# max_samples = 95
# [[  15    0]
#  [1501    0]]
# max_samples = 100
# [[  15    0]
#  [1493    8]]
# max_samples = 105
# [[  15    0]
#  [1501    0]]
# max_samples = 110
# [[  15    0]
#  [1440   61]]
# max_samples = 115
# [[  15    0]
#  [1389  112]]
# max_samples = 120
# [[  15    0]
#  [1358  143]]
# max_samples = 125
# [[  15    0]
#  [1262  239]]
# max_samples = 130
# [[  15    0]
#  [1045  456]]
# max_samples = 135
# [[ 15   0]
#  [838 663]]
# auc_IF = 0.7208527648234511
# max_samples = 140
# [[ 15   0]
#  [821 680]]
# auc_IF = 0.7265156562291806
# max_samples = 145
# [[ 13   2]
#  [696 805]]
# auc_IF = 0.7014878969575838
# max_samples = 150
# [[ 14   1]
#  [525 976]]
# auc_IF = 0.7917832556073728
# max_samples = 155
# [[ 15   0]
#  [538 963]]
# auc_IF = 0.820786142571619
# max_samples = 160
# [[  15    0]
#  [ 461 1040]]
# auc_IF = 0.846435709526982
# max_samples = 165
# [[ 15   0]
#  [521 980]]
# auc_IF = 0.8264490339773485
# max_samples = 170
# [[  15    0]
#  [ 411 1090]]
# auc_IF = 0.8630912724850099
# max_samples = 175
# [[  15    0]
#  [ 383 1118]]
# auc_IF = 0.8724183877415057
# max_samples = 180
# [[   8    7]
#  [ 422 1079]]
# max_samples = 185
# [[  10    5]
#  [ 305 1196]]
# auc_IF = 0.7317343992893627
# max_samples = 190
# [[   1   14]
#  [ 301 1200]]
# max_samples = 195
# [[  15    0]
#  [ 304 1197]]
# auc_IF = 0.8987341772151899
# max_samples = 200
# [[   3   12]
#  [ 280 1221]]
# max_samples = 205
# [[  15    0]
#  [ 291 1210]]
# auc_IF = 0.9030646235842772
# max_samples = 210
# [[  13    2]
#  [ 253 1248]]
# auc_IF = 0.8490561847657118
# max_samples = 215
# [[  12    3]
#  [ 237 1264]]
# auc_IF = 0.8210526315789475
# max_samples = 220
# [[  15    0]
#  [ 246 1255]]
# auc_IF = 0.9180546302465024
# max_samples = 225
# [[   0   15]
#  [ 147 1354]]
# max_samples = 230
# [[   0   15]
#  [ 168 1333]]
# max_samples = 235
# [[   0   15]
#  [ 187 1314]]
# max_samples = 240
# [[   0   15]
#  [ 179 1322]]
# max_samples = 245
# [[   0   15]
#  [ 171 1330]]
# max_samples = 250
# [[   0   15]
#  [ 151 1350]]
# max_samples = 255
# [[   8    7]
#  [ 124 1377]]
# auc_IF = 0.7253608705307573
# max_samples = 260
# [[   1   14]
#  [ 169 1332]]
# max_samples = 265
# [[   0   15]
#  [ 134 1367]]
# max_samples = 270
# [[   4   11]
#  [ 116 1385]]
# max_samples = 275
# [[   0   15]
#  [ 106 1395]]
# max_samples = 280
# [[   0   15]
#  [ 125 1376]]
# max_samples = 285
# [[   2   13]
#  [ 115 1386]]
# max_samples = 290
# [[   0   15]
#  [ 112 1389]]
# max_samples = 295
# [[   0   15]
#  [ 109 1392]]
# max_samples = 300
# [[   0   15]
#  [  84 1417]]
# max_samples = 305
# [[   0   15]
#  [  81 1420]]
# max_samples = 310
# [[   0   15]
#  [ 100 1401]]
# max_samples = 315
# [[   1   14]
#  [  93 1408]]
# max_samples = 320
# [[   0   15]
#  [  67 1434]]
# max_samples = 325
# [[   0   15]
#  [  98 1403]]
# max_samples = 330
# [[   0   15]
#  [  63 1438]]
# max_samples = 335
# [[   0   15]
#  [  67 1434]]
# max_samples = 340
# [[   0   15]
#  [  79 1422]]
# max_samples = 345
# [[   0   15]
#  [  60 1441]]
# max_samples = 350
# [[   0   15]
#  [  70 1431]]
# max_samples = 355
# [[   0   15]
#  [  63 1438]]
# max_samples = 360
# [[   0   15]
#  [  76 1425]]
# max_samples = 365
# [[   0   15]
#  [  61 1440]]
# max_samples = 370
# [[   0   15]
#  [  69 1432]]
# max_samples = 375
# [[   0   15]
#  [  56 1445]]
# max_samples = 380
# [[   0   15]
#  [  52 1449]]
# max_samples = 385
# [[   0   15]
#  [  53 1448]]
# max_samples = 390
# [[   0   15]
#  [  54 1447]]
# max_samples = 395
# [[   0   15]
#  [  61 1440]]
# max_samples = 400
# [[   0   15]
#  [  49 1452]]
# max_samples = 405
# [[   0   15]
#  [  63 1438]]
# max_samples = 410
# [[   0   15]
#  [  55 1446]]
# max_samples = 415
# [[   0   15]
#  [  43 1458]]
# max_samples = 420
# [[   0   15]
#  [  47 1454]]
# max_samples = 425
# [[   0   15]
#  [  40 1461]]
# max_samples = 430
# [[   0   15]
#  [  46 1455]]
# max_samples = 435
# [[   0   15]
#  [  36 1465]]
# max_samples = 440
# [[   0   15]
#  [  36 1465]]
# max_samples = 445
# [[   0   15]
#  [  44 1457]]
# max_samples = 450
# [[   0   15]
#  [  40 1461]]
# max_samples = 455
# [[   0   15]
#  [  43 1458]]
# max_samples = 460
# [[   0   15]
#  [  42 1459]]
# max_samples = 465
# [[   0   15]
#  [  48 1453]]
# max_samples = 470
# [[   0   15]
#  [  43 1458]]
# max_samples = 475
# [[   0   15]
#  [  36 1465]]
# max_samples = 480
# [[   0   15]
#  [  33 1468]]
# max_samples = 485
# [[   0   15]
#  [  30 1471]]
# max_samples = 490
# [[   0   15]
#  [  41 1460]]
# max_samples = 495
# [[   0   15]
#  [  31 1470]]
# max_samples = 500
# [[   0   15]
#  [  28 1473]]
# max_samples = 505
# [[   0   15]
#  [  29 1472]]
# max_samples = 510
# [[   0   15]
#  [  32 1469]]
# max_samples = 515
# [[   0   15]
#  [  36 1465]]
# max_samples = 520
# [[   0   15]
#  [  31 1470]]
# max_samples = 525
# [[   0   15]
#  [  27 1474]]
# max_samples = 530
# [[   0   15]
#  [  30 1471]]
# max_samples = 535
# [[   0   15]
#  [  29 1472]]
# max_samples = 540
# [[   0   15]
#  [  26 1475]]
# max_samples = 545
# [[   0   15]
#  [  27 1474]]
# max_samples = 550
# [[   0   15]
#  [  26 1475]]
# max_samples = 555
# [[   0   15]
#  [  21 1480]]
# max_samples = 560
# [[   0   15]
#  [  26 1475]]
# max_samples = 565
# [[   0   15]
#  [  27 1474]]
# max_samples = 570
# [[   0   15]
#  [  22 1479]]
# max_samples = 575
# [[   0   15]
#  [  23 1478]]
# max_samples = 580
# [[   0   15]
#  [  19 1482]]
# max_samples = 585
# [[   0   15]
#  [  28 1473]]
# max_samples = 590
# [[   0   15]
#  [  23 1478]]
# max_samples = 595
# [[   0   15]
#  [  30 1471]]
# max_samples = 600
# [[   0   15]
#  [  21 1480]]
# max_samples = 605
# [[   0   15]
#  [  20 1481]]
# max_samples = 610
# [[   0   15]
#  [  17 1484]]
# max_samples = 615
# [[   0   15]
#  [  21 1480]]
# max_samples = 620
# [[   0   15]
#  [  17 1484]]
# max_samples = 625
# [[   0   15]
#  [  21 1480]]
# max_samples = 630
# [[   0   15]
#  [  21 1480]]
# max_samples = 635
# [[   0   15]
#  [  19 1482]]
# max_samples = 640
# [[   0   15]
#  [  18 1483]]
# max_samples = 645
# [[   0   15]
#  [  21 1480]]
# max_samples = 650
# [[   0   15]
#  [  21 1480]]
# max_samples = 655
# [[   0   15]
#  [  18 1483]]
# max_samples = 660
# [[   0   15]
#  [  19 1482]]
# max_samples = 665
# [[   0   15]
#  [  19 1482]]
# max_samples = 670
# [[   0   15]
#  [  11 1490]]
# max_samples = 675
# [[   0   15]
#  [  19 1482]]
# max_samples = 680
# [[   0   15]
#  [  20 1481]]
# max_samples = 685
# [[   0   15]
#  [  19 1482]]
# max_samples = 690
# [[   0   15]
#  [  18 1483]]
# max_samples = 695
# [[   0   15]
#  [  15 1486]]
# max_samples = 700
# [[   0   15]
#  [  17 1484]]
# max_samples = 705
# [[   0   15]
#  [  15 1486]]
# max_samples = 710
# [[   0   15]
#  [  16 1485]]
# max_samples = 715
# [[   0   15]
#  [  16 1485]]
# max_samples = 720
# [[   0   15]
#  [  13 1488]]
# max_samples = 725
# [[   0   15]
#  [  16 1485]]
# max_samples = 730
# [[   0   15]
#  [  18 1483]]
# max_samples = 735
# [[   0   15]
#  [  14 1487]]
# max_samples = 740
# [[   0   15]
#  [  15 1486]]
# max_samples = 745
# [[   0   15]
#  [  18 1483]]
# max_samples = 750
# [[   0   15]
#  [  18 1483]]
# max_samples = 755
# [[   0   15]
#  [  12 1489]]
# max_samples = 760
# [[   0   15]
#  [  10 1491]]
# max_samples = 765
# [[   0   15]
#  [  13 1488]]
# max_samples = 770
# [[   0   15]
#  [  16 1485]]
# max_samples = 775
# [[   0   15]
#  [  14 1487]]
# max_samples = 780
# [[   0   15]
#  [  12 1489]]
# max_samples = 785
# [[   0   15]
#  [  17 1484]]
# max_samples = 790
# [[   0   15]
#  [  13 1488]]
# max_samples = 795
# [[   0   15]
#  [  11 1490]]
# max_samples = 800
# [[   0   15]
#  [  14 1487]]
# max_samples = 805
# [[   0   15]
#  [  12 1489]]
# max_samples = 810
# [[   0   15]
#  [  18 1483]]
# max_samples = 815
# [[   0   15]
#  [   8 1493]]
# max_samples = 820
# [[   0   15]
#  [  13 1488]]
# max_samples = 825
# [[   0   15]
#  [  11 1490]]
# max_samples = 830
# [[   0   15]
#  [  12 1489]]
# max_samples = 835
# [[   0   15]
#  [  12 1489]]
# max_samples = 840
# [[   0   15]
#  [  10 1491]]
# max_samples = 845
# [[   0   15]
#  [  12 1489]]
# max_samples = 850
# [[   0   15]
#  [  11 1490]]
# max_samples = 855
# [[   0   15]
#  [  13 1488]]
# max_samples = 860
# [[   0   15]
#  [  14 1487]]
# max_samples = 865
# [[   0   15]
#  [  10 1491]]
# max_samples = 870
# [[   0   15]
#  [  10 1491]]
# max_samples = 875
# [[   0   15]
#  [  12 1489]]
# max_samples = 880
# [[   0   15]
#  [   9 1492]]
# max_samples = 885
# [[   0   15]
#  [   9 1492]]
# max_samples = 890
# [[   0   15]
#  [   8 1493]]
# max_samples = 895
# [[   0   15]
#  [   9 1492]]
# max_samples = 900
# [[   0   15]
#  [   9 1492]]
# max_samples = 905
# [[   0   15]
#  [   7 1494]]
# max_samples = 910
# [[   0   15]
#  [   5 1496]]
# max_samples = 915
# [[   0   15]
#  [   7 1494]]
# max_samples = 920
# [[   0   15]
#  [  11 1490]]
# max_samples = 925
# [[   0   15]
#  [   9 1492]]
# max_samples = 930
# [[   0   15]
#  [  10 1491]]
# max_samples = 935
# [[   0   15]
#  [   9 1492]]
# max_samples = 940
# [[   0   15]
#  [   9 1492]]
# max_samples = 945
# [[   0   15]
#  [  11 1490]]
# max_samples = 950
# [[   0   15]
#  [   7 1494]]
# max_samples = 955
# [[   0   15]
#  [   8 1493]]
# max_samples = 960
# [[   0   15]
#  [   7 1494]]
# max_samples = 965
# [[   0   15]
#  [   7 1494]]
# max_samples = 970
# [[   0   15]
#  [   7 1494]]
# max_samples = 975
# [[   0   15]
#  [   8 1493]]
# max_samples = 980
# [[   0   15]
#  [   7 1494]]
# max_samples = 985
# [[   0   15]
#  [   5 1496]]
# max_samples = 990
# [[   0   15]
#  [  11 1490]]
# max_samples = 995
# [[   0   15]
#  [   5 1496]]
# max_samples = 1000
# [[   0   15]
#  [   6 1495]]
# max_samples = 1005
# [[   0   15]
#  [   8 1493]]
# max_samples = 1010
# [[   0   15]
#  [  10 1491]]
# max_samples = 1015
# [[   0   15]
#  [   5 1496]]
# max_samples = 1020
# [[   0   15]
#  [   7 1494]]
# max_samples = 1025
# [[   0   15]
#  [   9 1492]]
# max_samples = 1030
# [[   0   15]
#  [   7 1494]]
# max_samples = 1035
# [[   0   15]
#  [   9 1492]]
# max_samples = 1040
# [[   0   15]
#  [   9 1492]]
# max_samples = 1045
# [[   0   15]
#  [   6 1495]]
# max_samples = 1050
# [[   0   15]
#  [   7 1494]]
# max_samples = 1055
# [[   0   15]
#  [   7 1494]]
# max_samples = 1060
# [[   0   15]
#  [   5 1496]]
# max_samples = 1065
# [[   0   15]
#  [   7 1494]]
# max_samples = 1070
# [[   0   15]
#  [   7 1494]]
# max_samples = 1075
# [[   0   15]
#  [   9 1492]]
# max_samples = 1080
# [[   0   15]
#  [   8 1493]]
# max_samples = 1085
# [[   0   15]
#  [  12 1489]]
# max_samples = 1090
# [[   0   15]
#  [   4 1497]]
# max_samples = 1095
# [[   0   15]
#  [   4 1497]]
# max_samples = 1100
# [[   0   15]
#  [   5 1496]]
# max_samples = 1105
# [[   0   15]
#  [   6 1495]]
# max_samples = 1110
# [[   0   15]
#  [   5 1496]]
# max_samples = 1115
# [[   0   15]
#  [   5 1496]]
# max_samples = 1120
# [[   0   15]
#  [   6 1495]]
# max_samples = 1125
# [[   0   15]
#  [   6 1495]]
# max_samples = 1130
# [[   0   15]
#  [   7 1494]]
# max_samples = 1135
# [[   0   15]
#  [   6 1495]]
# max_samples = 1140
# [[   0   15]
#  [   4 1497]]
# max_samples = 1145
# [[   0   15]
#  [   5 1496]]
# max_samples = 1150
# [[   0   15]
#  [   5 1496]]
# max_samples = 1155
# [[   0   15]
#  [   4 1497]]
# max_samples = 1160
# [[   0   15]
#  [   5 1496]]
# max_samples = 1165
# [[   0   15]
#  [   3 1498]]
# max_samples = 1170
# [[   0   15]
#  [   5 1496]]
# max_samples = 1175
# [[   0   15]
#  [   5 1496]]
# max_samples = 1180
# [[   0   15]
#  [   4 1497]]
# max_samples = 1185
# [[   0   15]
#  [   6 1495]]
# max_samples = 1190
# [[   0   15]
#  [   5 1496]]
# max_samples = 1195
# [[   0   15]
#  [   5 1496]]
# max_samples = 1200
# [[   0   15]
#  [   6 1495]]
# max_samples = 1205
# [[   0   15]
#  [   5 1496]]
# max_samples = 1210
# [[   0   15]
#  [   4 1497]]
# max_samples = 1215
# [[   0   15]
#  [   4 1497]]
# max_samples = 1220
# [[   0   15]
#  [   7 1494]]
# max_samples = 1225
# [[   0   15]
#  [   4 1497]]
# max_samples = 1230
# [[   0   15]
#  [   3 1498]]
# max_samples = 1235
# [[   0   15]
#  [   4 1497]]
# max_samples = 1240
# [[   0   15]
#  [   5 1496]]
# max_samples = 1245
# [[   0   15]
#  [   4 1497]]
# max_samples = 1250
# [[   0   15]
#  [   7 1494]]
# max_samples = 1255
# [[   0   15]
#  [   3 1498]]
# max_samples = 1260
# [[   0   15]
#  [   4 1497]]
# max_samples = 1265
# [[   0   15]
#  [   4 1497]]
# max_samples = 1270
# [[   0   15]
#  [   4 1497]]
# max_samples = 1275
# [[   0   15]
#  [   4 1497]]
# max_samples = 1280
# [[   0   15]
#  [   3 1498]]
# max_samples = 1285
# [[   0   15]
#  [   4 1497]]
# max_samples = 1290
# [[   0   15]
#  [   5 1496]]
# max_samples = 1295
# [[   0   15]
#  [   6 1495]]
# max_samples = 1300
# [[   0   15]
#  [   4 1497]]
# max_samples = 1305
# [[   0   15]
#  [   5 1496]]
# max_samples = 1310
# [[   0   15]
#  [   3 1498]]
# max_samples = 1315
# [[   0   15]
#  [   4 1497]]
# max_samples = 1320
# [[   0   15]
#  [   3 1498]]
# max_samples = 1325
# [[   0   15]
#  [   4 1497]]
# max_samples = 1330
# [[   0   15]
#  [   4 1497]]
# max_samples = 1335
# [[   0   15]
#  [   3 1498]]
# max_samples = 1340
# [[   0   15]
#  [   4 1497]]
# max_samples = 1345
# [[   0   15]
#  [   3 1498]]
# max_samples = 1350
# [[   0   15]
#  [   5 1496]]
# max_samples = 1355
# [[   0   15]
#  [   4 1497]]
# max_samples = 1360
# [[   0   15]
#  [   3 1498]]
# max_samples = 1365
# [[   0   15]
#  [   3 1498]]
# max_samples = 1370
# [[   0   15]
#  [   4 1497]]
# max_samples = 1375
# [[   0   15]
#  [   3 1498]]
# max_samples = 1380
# [[   0   15]
#  [   4 1497]]
# max_samples = 1385
# [[   0   15]
#  [   3 1498]]
# max_samples = 1390
# [[   0   15]
#  [   3 1498]]
# max_samples = 1395
# [[   0   15]
#  [   4 1497]]
# max_samples = 1400
# [[   0   15]
#  [   3 1498]]
# max_samples = 1405
# [[   0   15]
#  [   4 1497]]
# max_samples = 1410
# [[   0   15]
#  [   3 1498]]
# max_samples = 1415
# [[   0   15]
#  [   3 1498]]
# max_samples = 1420
# [[   0   15]
#  [   4 1497]]
# max_samples = 1425
# [[   0   15]
#  [   4 1497]]
# max_samples = 1430
# [[   0   15]
#  [   3 1498]]
# max_samples = 1435
# [[   0   15]
#  [   3 1498]]
# max_samples = 1440
# [[   0   15]
#  [   4 1497]]
# max_samples = 1445
# [[   0   15]
#  [   3 1498]]
# max_samples = 1450
# [[   0   15]
#  [   3 1498]]
# max_samples = 1455
# [[   0   15]
#  [   4 1497]]
# max_samples = 1460
# [[   0   15]
#  [   4 1497]]
# max_samples = 1465
# [[   0   15]
#  [   3 1498]]
# max_samples = 1470
# [[   0   15]
#  [   3 1498]]
# max_samples = 1475
# [[   0   15]
#  [   3 1498]]
# max_samples = 1480
# [[   0   15]
#  [   3 1498]]
# max_samples = 1485
# [[   0   15]
#  [   3 1498]]
# max_samples = 1490
# [[   0   15]
#  [   4 1497]]
# max_samples = 1495
# [[   0   15]
#  [   3 1498]]
# max_samples = 1500
# [[   0   15]
#  [   3 1498]]
# max_samples = 1505
# [[   0   15]
#  [   4 1497]]
# max_samples = 1510
# [[   0   15]
#  [   3 1498]]
# max_samples = 1515
# [[   0   15]
#  [   3 1498]]

# %%
visu.plot_2D(max_samples_IF, roc_auc_IF,'Max_samples', 'ROC AUC', "ROC AUC Min = "+str(min_roc_auc), link="b").show()

# %%
visu.plot_2D(range(min_sample_size, len(X_brut), sample_size_step), specificities,'Max_samples', 'Specificity', "ROC AUC Min = "+str(min_roc_auc), link="b").show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# IForest ne détecte pas les anomalies et fais de fausses alertes.
