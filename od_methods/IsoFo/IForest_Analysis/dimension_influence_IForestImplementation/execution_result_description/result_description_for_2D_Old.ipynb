# %% [markdown]
# # Result description

# %% [markdown]
# ## Test with 2 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
from IForest_DODiMDS import iforest_D as IFD
from metrics import performances
perf = performances.performances()
from metrics import visualization
visu = visualization.visualization()
from metrics import functions
func = functions.functions()

import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score
from imblearn.metrics import specificity_score
from imblearn.metrics import sensitivity_score
from imblearn.metrics import specificity_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve

import matplotlib.cm as cm
from mpl_toolkits import mplot3d

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset TwoD_V1_0
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_0()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 202 1298]]
# ROC AUC : 0.43266666666666664
# Specificity : 0.0
# Precision : 0.9885757806549885
# Recall : 0.8653333333333333
# f1_score : 0.9228581585495913
# False alarm rate (%) : 13.466666666666672
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 2     0.203131  6.482506  0.606371
# 5     3.106334  6.076085  0.600562
# 19    5.589001  4.085129  0.603084
# 27    0.455350  6.459653  0.600335
# 29   -6.375658  0.479525  0.614187
# 33   -0.541941 -6.542501  0.636999
# ...

# %% [markdown]
# ### Dataset TwoD_V1_1
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_1()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 190 1310]]
# ROC AUC : 0.43666666666666665
# Specificity : 0.0
# Precision : 0.9886792452830189
# Recall : 0.8733333333333333
# f1_score : 0.927433628318584
# False alarm rate (%) : 12.666666666666671
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 7    -6.702078 -0.822866  0.645569
# 8     5.554390 -3.953190  0.609794
# 14    0.836414 -6.300447  0.627330
# 15    6.600900  1.560175  0.667223
# 22    6.822442  0.324249  0.698904
# 26   -2.846081 -6.269712  0.627427
# ...

# %% [markdown]
# ### Dataset TwoD_V2
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V2()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 178 1322]]
# ROC AUC : 0.44066666666666665
# Specificity : 0.0
# Precision : 0.9887808526551982
# Recall : 0.8813333333333333
# f1_score : 0.9319703912583714
# False alarm rate (%) : 11.86666666666667
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 4    -0.677426 -6.602349  0.604819
# 9    -1.347989  6.713981  0.658623
# 13    2.234380 -6.543622  0.604557
# 26    2.358630  6.514871  0.637472
# 50   -1.824710  6.495816  0.625002
# 59    1.940972  6.598118  0.636377
# ...

# %% [markdown]
# ### Dataset TwoD_V3_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_0_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 124 1376]]
# ROC AUC : 0.45866666666666667
# Specificity : 0.0
# Precision : 0.9892163910855499
# Recall : 0.9173333333333333
# f1_score : 0.9519197509512279
# False alarm rate (%) : 8.266666666666666
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 19   -2.668775 -8.494902  0.615801
# 46    0.143770  8.639547  0.620445
# 73   -2.624391  8.580181  0.629755
# 100   3.189854  8.332516  0.619269
# 103   0.201188  8.765202  0.640590
# 107   3.509355  8.259046  0.624869
# ...

# %% [markdown]
# ### Dataset TwoD_V3_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_1_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 117 1383]]
# ROC AUC : 0.461
# Specificity : 0.0
# Precision : 0.9892703862660944
# Recall : 0.922
# f1_score : 0.9544513457556936
# False alarm rate (%) : 7.799999999999995
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 2    -8.515358 -2.442636  0.612526
# 3     8.804022  0.685126  0.650788
# 25   -8.695676  1.661084  0.641001
# 31   -8.937368  0.562304  0.669778
# 56    8.844902 -1.301756  0.659102
# 90   -8.882353 -0.829610  0.673899
# 105   1.280136  8.575375  0.610914
# ...

# %% [markdown]
# ### Dataset TwoD_V3_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_2_0()
x_lim = 12
y_lim = 9
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   5   10]
#  [ 166 1334]]
# ROC AUC : 0.6113333333333333
# Specificity : 0.3333333333333333
# Precision : 0.9925595238095238
# Recall : 0.8893333333333333
# f1_score : 0.9381153305203938
# False alarm rate (%) : 11.06666666666667
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 34    8.723502 -2.203662  0.660678
# 35    8.469724 -1.092604  0.601454
# 36   -1.659311  8.591255  0.623965
# 45   -0.463911  8.802505  0.678055
# 61   -8.740915 -1.751509  0.629633
# 64   -3.097710  8.269712  0.601051
# ...

# %% [markdown]
# ### Dataset 4.2.0
# #### Conclusion on this dataset :
# EIF is better than IForest

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V4_2_0()
x_lim = 17
y_lim = 12
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  14    1]
#  [ 112 1388]]
# ROC AUC : 0.9293333333333333
# Specificity : 0.9333333333333333
# Precision : 0.9992800575953924
# Recall : 0.9253333333333333
# f1_score : 0.9608861197646245
# False alarm rate (%) : 7.466666666666666
# ****************************************************************
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#              0         1         2
# 14   -9.833627  1.197827  0.627815
# 30    9.828632 -0.031127  0.613507
# 34   -9.601547 -2.648503  0.624239
# 55   -9.753306 -1.473940  0.626476
# 57    0.734276 -9.830159  0.637882
# 63   -1.499269  9.885414  0.632022
# 69    9.955211  0.067153  0.652693
# ...

# %% [markdown]
# ### Dataset TwoD_V5_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_0_0()
x_lim = 30
y_lim = 20
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  66 1434]]
# ROC AUC : 0.978
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.956
# f1_score : 0.9775051124744376
# False alarm rate (%) : 4.400000000000004
# ****************************************************************
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#               0         1         2
# 54    -2.503758 -9.529363  0.602411
# 56    -0.713128  9.939985  0.664339
# 70     0.892557  9.778815  0.631576
# 76     1.819105 -9.796086  0.621019
# 78    -1.623038 -9.738521  0.617181
# 88     0.449610  9.778407  0.626090
# 107   -9.824901 -0.577122  0.612575
# 114   -0.287528  9.947739  0.661816
# ...

# %% [markdown]
# ### Dataset TwoD_V5_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_1_0()
x_lim = 40
y_lim = 30
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  69 1431]]
# ROC AUC : 0.977
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.954
# f1_score : 0.9764585465711361
# False alarm rate (%) : 4.600000000000004
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#               0         1         2
# 0     -9.950855  0.830797  0.649431
# 10    -1.894561  9.775693  0.636132
# 16    -9.799835  1.895527  0.611235
# 27     1.210838  9.831302  0.655267
# 66    -1.727424  9.652656  0.602315
# 75    -9.684534 -2.362096  0.606959
# 95     3.185275  9.381740  0.602081
# ...

# %% [markdown]
# ### Dataset TwoD_V6_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_0_0()
x_lim = 30
y_lim = 20
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  66 1434]]
# ROC AUC : 0.978
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.956
# f1_score : 0.9775051124744376
# False alarm rate (%) : 4.400000000000004
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#               0          1         2
# 13     0.817795   9.963613  0.654722
# 23    -9.624421   2.057162  0.604172
# 29    -9.518967  -2.783386  0.605906
# 37    -9.979513   0.010553  0.657736
# 61    -9.491853  -2.773065  0.601861
# 83    -9.860956  -1.439532  0.635688
# 94     0.624635   9.756730  0.611265
# ...

# %% [markdown]
# ### Dataset TwoD_V6_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_1_0()
x_lim = 40
y_lim = 30
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  15    0]
#  [  53 1447]]
# ROC AUC : 0.9823333333333333
# Specificity : 1.0
# Precision : 1.0
# Recall : 0.9646666666666667
# f1_score : 0.982015609093994
# False alarm rate (%) : 3.5333333333333328
# ****************************************************************
# Model is an instance of IsolationForest
# /Users/maurrastogbe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
# Abnormal predicted data
#               0          1         2
# 33    -9.941839  -0.288680  0.629318
# 72     0.676906  -9.894116  0.636530
# 142   -9.883271   1.197120  0.606479
# 171    1.814243  -9.801863  0.622114
# 172    0.284540  -9.961900  0.656015
# 194    0.714046  -9.773656  0.606475
# ...

# %%
n = 256
2.0*(np.log(n-1)+0.5772156649) - (2.0*(n-1.)/(n*1.0))
# Out:
# 10.244770920116851
