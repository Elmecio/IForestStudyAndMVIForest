# %% [markdown]
# # Result description

# %% [markdown]
# ## Test with 3 dimensions datasets

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from experiments import trainning_parametors
t_parametors = trainning_parametors.functions_train_parametors()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset ThreeD_V1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V1_0()
x_lim = 7
y_lim = 10
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  0   7]
#  [ 12 738]]
# ROC AUC : 0.492
# Specificity : 0.0
# Precision : 0.9906040268456375
# Recall : 0.984
# f1_score : 0.9872909698996656
# False alarm rate (%) : 1.6000000000000014
# CPU Time (s) : 1.5036532878875732
# Memory Consumption (o) : 0
# ****************************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ea2b8706aff> in <module>
#       9 print("################################################## IFOREST ###################################")
#      10 t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold,
# ---> 11                 y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
#      12 print("################################################## EIF ###################################")
#      13 t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold,
#
# ~/Documents/GitHub/OD_Jupyter/experiments/trainning_parametors.py in execute_IForest(self, X_brut, max_samples, n_trees, threshold, y_transform, x_lim, y_lim, z_lim, X_train, n_dimensions)
#      62                         X_brut=X_brut, y_brut = y_transform, X_normal=X_normal,
#      63                         X_abnormal=X_abnormal, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim,
# ---> 64                         outlier_label=-1, pathLength=IFD_paths_length, model=func_IF)
#      65
#      66         fig.show()
#
# ~/Documents/GitHub/OD_Jupyter/metrics/visualization.py in result_description_3D(self, title, scores, X_brut, y_brut, X_normal, X_abnormal, x_lim, y_lim, z_lim, outlier_label, pathLength, model)
#      66                                   y_brut=y_brut,X_normal=X_normal, X_abnormal=X_abnormal,
#      67                                   x_lim=x_lim, y_lim=y_lim, z_lim = z_lim,
# ---> 68                                   outlier_label=outlier_label,pathLength=pathLength, model = model)
#      69
#      70
#
# ~/Documents/GitHub/OD_Jupyter/metrics/visualization.py in description_3D_V3(self, title, scores, X_brut, y_brut, X_normal, X_abnormal, x_lim, y_lim, outlier_label, pathLength, model, z_lim)
#     449                                  X_scores=pathLength)
#     450             """
# --> 451             return fig, axs, None, None, None
#     452
#     453     def metrics_visualization(self, title, axe_x, x_title, specifities, recalls, aucs,
#
# NameError: name 'axs' is not defined

# %% [markdown]
# ### Dataset ThreeD_V1_1
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V1_1()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)

# %% [markdown]
# ### Dataset ThreeD_V2
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V2()
x_lim = 10
y_lim = 7
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)

# %% [markdown]
# ### Dataset ThreeD_V4_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V4_2_0()
x_lim = 17
y_lim = 12
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim)
