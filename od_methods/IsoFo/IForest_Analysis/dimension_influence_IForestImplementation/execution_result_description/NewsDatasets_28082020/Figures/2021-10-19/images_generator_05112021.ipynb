# %% [markdown]
# ### File created the 05 11 2021 in order to generate figure for execution of MVIForest, IForest, EIF on synthetics dataset which will have the same dimension from the results obtain on 19-10-2021
# - 2.0.0 ==> Synthetic 5 (TwoD2_V2_0_0())
# - 3.3.0 ==> Synthetic 1 (TwoD2_V3_3_0())
# - 3.4.0 ==> Synthetic 2 (TwoD2_V3_4_0())
# - 4.3.0 ==> Synthetic 6 (TwoD2_V4_3_0())
# - 4.3.1 ==> Synthetic 3 (TwoD2_V4_3_1())
# - 4.3.2 ==> Synthetic 4 (TwoD2_V4_3_2())
#
# The result file which have been saved during the experiment execution if structured as follow
# **XBrut**(n-1 columns) **YBrut** (1 Column from the dataset) **YClassified** (1 Column from the execution) **scores** (1 column) **pathLength** (1 column)
#
# The function used to save the results data is "save_execution_results_data" defined in performances.py
# **save_execution_results_data(self, YClassified,
#                             scores, pathLengths,
#                             data_name = "Data", method_name="Method",
#                             execution_object="Experiment",
#                             alldataset = None,
#                             XBrut = None, YBrut = None)**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
import sys
sys.path.append('../../../../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../../../../")

util = datat.utilitaries()

from metrics import useful_infos as ue

#from experiments import trainning_parametors
#t_parametors = trainning_parametors.functions_train_parametors()

image_folder = "saved_images/05_11_2021/"

# %%
def show_figure(data_path, dataset_name, method_name) :
    # Load the dataset
    dataset = datat.load_data_from_CSV(data_path);
    # Split in execution results
    XBrut, YBrut, YClassified, Scores, PathLengths = util.split_in_results(dataset)
     
    #return
    # Concat in order to put the YClassified at the end and get Classified normal and classified abnormal
    # Important : In this case splitOn="PredictClass" to split on the classification
    X_normal, X_abnormal, pdataX = util.concat_columns_split(dataX=XBrut, dataScores=Scores, dataY=YBrut, 
                             outlier_label=ue._OUTLIER_PREDICTION_LABEL, 
                             dataYPrediction=YClassified, dataPathLength=PathLengths, splitOn="PredictClass")
    
    # Plot classified normal data
    plt.scatter(X_normal[0], X_normal[1], c="b")
    plt.xlim(-30,30)
    plt.ylim(-20,20)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(method_name+" "+dataset_name+" Classified normal")
    # Save picture
    plt.savefig(image_folder+method_name+"_"+dataset_name+"classiedNormal.pdf", bbox_inches='tight', pad_inches=0.05)
    
    plt.show()
    
    # Plot classified abnormal data
    plt.scatter(X_abnormal[0], X_abnormal[1], c="b")
    plt.xlim(-30,30)
    plt.ylim(-20,20)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(method_name+" "+dataset_name+" Classified abnormal")
    # Save picture
    plt.savefig(image_folder+method_name+"_"+dataset_name+"classifiedAbnormal.pdf", bbox_inches='tight', pad_inches=0.05)
    
    plt.show()

# %% [markdown]
# ### MVIFOREST

# %%
#2.0.0 ==> Synthetic 5 (TwoD2_V2_0_0())
#3.3.0 ==> Synthetic 1 (TwoD2_V3_3_0())
#3.4.0 ==> Synthetic 2 (TwoD2_V3_4_0())
#4.3.0 ==> Synthetic 6 (TwoD2_V4_3_0())
#4.3.1 ==> Synthetic 3 (TwoD2_V4_3_1())
#4.3.2 ==> Synthetic 4 (TwoD2_V4_3_2())
#Synthetic\_1 = 3.3.0 (IF = 1, MVIF = 0, EIF = 2)
#Synthetic\_2 = 3.4.0 (IF = 2, MVIF = 4, EIF = 0)
#Synthetic\_3 = 4.3.1 (IF = 2, MVIF = 0, EIF = 3)
#Synthetic\_4 = 4.3.2 (IF = 3, MVIF = 1, EIF = 4)
#Synthetic\_5 = 2.0.0 (IF = 1, MVIF = 0, EIF = 4)
method_name = "MVIForest"

dataset_name = "Synthetic 1"
data_path = "MVIForest/Exec_0_Experiment_MVIForest_TwoD_V3.3.0_DataResults_2021-10-19-17-12-44-469662.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 2"
data_path = "MVIForest/Exec_4_Experiment_MVIForest_TwoD_V3.4.0_DataResults_2021-10-19-17-19-18-149729.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 3"
data_path = "MVIForest/Exec_0_Experiment_MVIForest_TwoD_V4.3.1_DataResults_2021-10-19-17-30-24-453641.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 4"
data_path = "MVIForest/Exec_1_Experiment_MVIForest_TwoD_V4.3.2_DataResults_2021-10-19-17-36-52-890393.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 5"
data_path = "MVIForest/Exec_0_Experiment_MVIForest_TwoD_V2.0.0_DataResults_2021-10-19-17-06-51-417427.csv"
show_figure(data_path, dataset_name, method_name)

# %% [markdown]
# ### IFOREST

# %%
#2.0.0 ==> Synthetic 5 (TwoD2_V2_0_0())
#3.3.0 ==> Synthetic 1 (TwoD2_V3_3_0())
#3.4.0 ==> Synthetic 2 (TwoD2_V3_4_0())
#4.3.0 ==> Synthetic 6 (TwoD2_V4_3_0())
#4.3.1 ==> Synthetic 3 (TwoD2_V4_3_1())
#4.3.2 ==> Synthetic 4 (TwoD2_V4_3_2())
#Synthetic\_1 = 3.3.0 (IF = 1, MVIF = 0, EIF = 2)
#Synthetic\_2 = 3.4.0 (IF = 2, MVIF = 4, EIF = 0)
#Synthetic\_3 = 4.3.1 (IF = 2, MVIF = 0, EIF = 3)
#Synthetic\_4 = 4.3.2 (IF = 3, MVIF = 1, EIF = 4)
#Synthetic\_5 = 2.0.0 (IF = 1, MVIF = 0, EIF = 4)
method_name = "IForest"

dataset_name = "Synthetic 1"
data_path = method_name+"/Exec_1_Experiment_IForest_TwoD_V3.3.0_DataResults_2021-10-19-17-11-54-738531.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 2"
data_path = method_name+"/Exec_2_Experiment_IForest_TwoD_V3.4.0_DataResults_2021-10-19-17-17-51-974985.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 3"
data_path = method_name+"/Exec_2_Experiment_IForest_TwoD_V4.3.1_DataResults_2021-10-19-17-29-45-100442.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 4"
data_path = method_name+"/Exec_3_Experiment_IForest_TwoD_V4.3.2_DataResults_2021-10-19-17-36-03-337399.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 5"
data_path = method_name+"/Exec_1_Experiment_IForest_TwoD_V2.0.0_DataResults_2021-10-19-17-05-58-120613.csv"
show_figure(data_path, dataset_name, method_name)

# %% [markdown]
# ### EIF

# %%
#2.0.0 ==> Synthetic 5 (TwoD2_V2_0_0())
#3.3.0 ==> Synthetic 1 (TwoD2_V3_3_0())
#3.4.0 ==> Synthetic 2 (TwoD2_V3_4_0())
#4.3.0 ==> Synthetic 6 (TwoD2_V4_3_0())
#4.3.1 ==> Synthetic 3 (TwoD2_V4_3_1())
#4.3.2 ==> Synthetic 4 (TwoD2_V4_3_2())
#Synthetic\_1 = 3.3.0 (IF = 1, MVIF = 0, EIF = 2)
#Synthetic\_2 = 3.4.0 (IF = 2, MVIF = 4, EIF = 0)
#Synthetic\_3 = 4.3.1 (IF = 2, MVIF = 0, EIF = 3)
#Synthetic\_4 = 4.3.2 (IF = 3, MVIF = 1, EIF = 4)
#Synthetic\_5 = 2.0.0 (IF = 1, MVIF = 0, EIF = 4)
method_folder_name = "Local EIF"
method_name = "EIF"

dataset_name = "Synthetic 1"
data_path = method_folder_name+"/Exec_2_Experiment_Local EIF_TwoD_V3.3.0_DataResults_2021-10-19-17-15-02-624582.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 2"
data_path = method_folder_name+"/Exec_0_Experiment_Local EIF_TwoD_V3.4.0_DataResults_2021-10-19-17-19-46-510496.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 3"
data_path = method_folder_name+"/Exec_3_Experiment_Local EIF_TwoD_V4.3.1_DataResults_2021-10-19-17-33-15-115077.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 4"
data_path = method_folder_name+"/Exec_4_Experiment_Local EIF_TwoD_V4.3.2_DataResults_2021-10-19-17-40-10-861780.csv"
show_figure(data_path, dataset_name, method_name)

dataset_name = "Synthetic 5"
data_path = method_folder_name+"/Exec_4_Experiment_Local EIF_TwoD_V2.0.0_DataResults_2021-10-19-17-10-21-839804.csv"
show_figure(data_path, dataset_name, method_name)
