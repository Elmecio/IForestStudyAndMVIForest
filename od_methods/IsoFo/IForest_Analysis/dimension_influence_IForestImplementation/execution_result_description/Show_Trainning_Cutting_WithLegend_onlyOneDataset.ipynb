# %% [markdown]
# # Show Trainning Splitting of IForest and EIF on one synthetic datasets HeatMap with colors legend

# %% [markdown]
# ## Test with 2 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from experiments import trainning_parametors
t_parametors = trainning_parametors.functions_train_parametors()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5
save_fig=True
show_legend = True

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset TwoD_V1_0
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_0()
#dataset_name = sys.path[len(sys.path)-1]+"+TwoD2_V1_0"
dataset_name = "TwoD_V1_0_0"
x_lim = 13
y_lim = 10

print("################################################## IFOREST ###################################")
t_parametors.show_cutting_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, dataset_name=dataset_name, save_fig=save_fig, show_legend=show_legend)
print("################################################## EIF    ###################################")
t_parametors.show_cutting_EIF(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, dataset_name=dataset_name, save_fig=save_fig, show_legend=show_legend)
# Out:
# ################################################## IFOREST ###################################
# ################################################## EIF    ###################################
# (<Figure size 864x1080 with 7 Axes>,
#  array([[<AxesSubplot:title={'center':'Dataset'}, xlabel='X', ylabel='Y'>,
#          <AxesSubplot:title={'center':'EIF scores Heat Map'}, xlabel='X', ylabel='Y'>],
#         [<AxesSubplot:title={'center':'Dataset'}, xlabel='X', ylabel='Y'>,
#          <AxesSubplot:title={'center':'EIF dataset splitting example'}, xlabel='X', ylabel='Y'>],
#         [<AxesSubplot:title={'center':'Dataset'}, xlabel='X', ylabel='Y'>,
#          <AxesSubplot:title={'center':'EIF random sample'}, xlabel='X', ylabel='Y'>]],
#        dtype=object))
