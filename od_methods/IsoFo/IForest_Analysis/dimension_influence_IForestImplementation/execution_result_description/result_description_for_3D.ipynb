# %% [markdown]
# # Result description

# %% [markdown]
# ## Test with 3 dimensions datasets

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

from experiments import trainning_parametors
t_parametors = trainning_parametors.functions_train_parametors()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset ThreeD_V1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V1_0()
x_lim = 7
y_lim = 10
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[  0   7]
#  [ 11 739]]
# ROC AUC : 0.49266666666666664
# Specificity : 0.0
# Precision : 0.9906166219839142
# Recall : 0.9853333333333333
# f1_score : 0.9879679144385026
# False alarm rate (%) : 1.4666666666666717
# CPU Time (s) : 1.7070248126983643
# Memory Consumption (o) : 0
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#             0         1         2         3         4  5
# 40   1.025659  6.918938 -0.276259  0.610405  8.840174 -1
# 41  -0.091600 -6.927283 -1.002178  0.603424  9.046160 -1
# 72  -0.228308  6.832800  1.503569  0.611829  8.798452 -1
# 157 -1.222963  6.889418 -0.200689  0.610556  8.835726 -1
# 170  0.052779  6.997819 -0.166568  0.619516  8.574831 -1
# 176 -1.281208  6.878374  0.215582  0.617310  8.638716 -1
# 601  0.402821 -6.963342 -0.591269  0.602128  9.084667 -1
# 625 -1.476839  6.774911 -0.958918  0.604745  9.007004 -1
# 627 -1.032158  6.922474 -0.118362  0.617527  8.632439 -1
# 654  1.338642  6.743572  1.316160  0.603150  9.054286 -1
# 699 -0.227734 -6.975871 -0.534189  0.615653  8.686872 -1
# ################################################## EIF ###################################
# Confusion matrice
# [[  0   7]
#  [  0 750]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9907529722589168
# Recall : 1.0
# f1_score : 0.9953550099535501
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.13326215744018555
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a240d8d10>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24adfad0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a242f82d0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a243376d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2436f090>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x10f3ff410>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x10f4330d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a241e5550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24297150>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V1_1
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V1_1()
x_lim = 10
y_lim = 7
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 101 1399]]
# ROC AUC : 0.4663333333333333
# Specificity : 0.0
# Precision : 0.9893917963224894
# Recall : 0.9326666666666666
# f1_score : 0.9601921757035002
# False alarm rate (%) : 6.733333333333336
# CPU Time (s) : 2.5278260707855225
# Memory Consumption (o) : 0
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#              0         1         2         3          4  5
# 5     1.939111  6.471326  1.833518  0.607353   9.928172 -1
# 45    1.317728 -6.757588  1.264354  0.604868  10.009796 -1
# 62   -6.929957  0.319697  0.934610  0.624774   9.365102 -1
# 66   -2.325532 -6.582651 -0.510493  0.605329   9.994625 -1
# 113  -1.006857  6.787234  1.385529  0.624897   9.361207 -1
# 127   6.978591 -0.366113 -0.406476  0.613507   9.727445 -1
# 129   1.668132  6.659435 -1.367211  0.613899   9.714734 -1
# 130  -6.988423 -0.374076  0.148362  0.637438   8.965562 -1
# 144  -6.870438 -1.318418  0.242596  0.611217   9.801916 -1
# 168  -0.668755 -6.640838  2.109986  0.604772  10.012971 -1
# 204  -6.834037  0.104014 -1.511659  0.604806  10.011840 -1
# 210  -1.426111 -6.728161  1.303097  0.610593   9.822232 -1
# 211  -6.881934 -0.223766 -1.260522  0.615643   9.658252 -1
# 238  -1.805276  6.668796 -1.126117  0.603438  10.056943 -1
# 247  -0.668602 -6.965687 -0.179380  0.632684   9.114616 -1
# 259   0.140524  6.751964  1.841529  0.612589   9.757275 -1
# 263  -1.359137  6.707582  1.470063  0.620048   9.516289 -1
# 268  -3.136442  6.216936  0.715848  0.604545  10.020438 -1
# 283  -1.477587 -6.803519  0.727234  0.614258   9.703093 -1
# 306  -6.634654 -0.171001  2.225338  0.605250   9.997238 -1
# 331   0.641262  6.777786 -1.628005  0.624212   9.383042 -1
# 339  -0.777365 -6.899808 -0.887895  0.616971   9.615340 -1
# 355  -1.117514  6.909966 -0.059375  0.634749   9.049753 -1
# 357   1.066471 -6.697887  1.732324  0.611746   9.784697 -1
# 359  -6.984696  0.111644 -0.448953  0.631680   9.146233 -1
# 402  -2.328861  6.545049  0.859502  0.601633  10.116582 -1
# 406  -1.005144  6.646656 -1.952346  0.606048   9.971012 -1
# 415   6.916381  0.345272  1.021990  0.606355   9.960907 -1
# 422   6.950059 -0.079685  0.830858  0.608055   9.905168 -1
# 434   0.783884 -6.494802  2.490597  0.611516   9.792163 -1
# 453  -0.621769 -6.944918 -0.617673  0.626274   9.317363 -1
# 469   2.031341 -6.544159  1.430956  0.603305  10.061329 -1
# 470  -1.177626  6.800478  1.169059  0.623002   9.421664 -1
# 488   0.275295  6.803962  1.621822  0.623638   9.401366 -1
# 495  -1.803528  6.712218 -0.832714  0.614859   9.683625 -1
# 510   1.619696 -6.749337 -0.907212  0.601594  10.117880 -1
# 513  -6.977515 -0.170606  0.534018  0.626368   9.314394 -1
# 531   1.309952 -6.770839  1.199902  0.605169   9.999908 -1
# 589  -6.404377  0.690757  2.739856  0.600212  10.163674 -1
# 594  -6.800192 -1.182689  1.165604  0.609371   9.862126 -1
# 615  -0.620314 -6.750777  1.744194  0.610558   9.823389 -1
# 619  -0.345755 -6.500764  2.573038  0.608227   9.899559 -1
# 637  -6.889892 -0.763126  0.973151  0.623089   9.418887 -1
# 644   0.701238  6.846865  1.276207  0.632114   9.132562 -1
# 692  -6.580003  2.096501  1.143783  0.605149  10.000562 -1
# 717   0.048774 -6.798129 -1.668252  0.610301   9.831760 -1
# 731   2.061917  6.488101  1.628816  0.612054   9.774665 -1
# 743   6.976927  0.566427 -0.040710  0.620303   9.508099 -1
# 749  -6.730003  0.456379 -1.870502  0.600978  10.138259 -1
# 762   0.530357  6.843389 -1.373588  0.630872   9.171722 -1
# 786  -0.852904  6.936853 -0.390679  0.642159   8.818661 -1
# 794   6.916078  1.074631  0.114146  0.606752   9.947880 -1
# 856   0.665894  6.874419  1.139713  0.639456   8.902631 -1
# 869   1.383436  6.601087 -1.873968  0.607312   9.929511 -1
# 870  -6.611452 -0.519525 -2.240267  0.605872   9.976782 -1
# 878  -6.432020 -0.425307  2.729145  0.601141  10.132861 -1
# 891  -2.270310 -6.581311 -0.729409  0.603047  10.069854 -1
# 899  -0.552629  6.777035 -1.663247  0.620820   9.491529 -1
# 928   0.373119  6.980299 -0.369073  0.647304   8.659782 -1
# 942   0.048503  6.984093  0.469137  0.642475   8.808863 -1
# 953  -6.897559  0.091474  1.189669  0.620532   9.500749 -1
# 981   0.391491 -6.692221  2.015170  0.613074   9.741516 -1
# 1013 -6.826601  1.547528 -0.051780  0.604241  10.030462 -1
# 1020  1.247730  6.518371 -2.225761  0.613486   9.728142 -1
# 1037  0.962068  6.793023 -1.388981  0.626313   9.316144 -1
# 1056 -0.948910  6.908797  0.606709  0.636779   8.986164 -1
# 1079 -0.240921 -6.973828  0.554691  0.639882   8.889370 -1
# 1092 -2.910598  6.349602 -0.459321  0.600412  10.157017 -1
# 1112 -6.579722  1.934104 -1.402318  0.601906  10.107546 -1
# 1115 -2.272224  6.610250 -0.376282  0.600368  10.158494 -1
# 1120 -0.559379  6.877661  1.176809  0.634661   9.052491 -1
# 1159  1.395465  6.851383 -0.333511  0.640212   8.879120 -1
# 1170 -1.628571 -6.555743  1.835753  0.611469   9.793717 -1
# 1172 -6.962305  0.421810  0.590247  0.629370   9.219184 -1
# 1178 -6.925287  0.989295 -0.248383  0.617900   9.585396 -1
# 1186  1.923550  6.725371  0.263317  0.631659   9.146910 -1
# 1208 -0.768653  6.955216  0.184764  0.638103   8.944826 -1
# 1216 -2.947028  6.349091  0.063803  0.602652  10.082901 -1
# 1229  6.927390 -0.718275  0.703811  0.605458   9.990381 -1
# 1238 -0.690623 -6.880844  1.084908  0.614666   9.689860 -1
# 1246  0.849598 -6.868962  1.046684  0.623661   9.400608 -1
# 1247 -6.615708  1.935276  1.219474  0.604061  10.036375 -1
# 1263  6.992370  0.281528 -0.165862  0.623437   9.407761 -1
# 1275  6.990252  0.167893  0.328917  0.621541   9.468416 -1
# 1287 -6.607238  1.964345  1.218918  0.604669  10.016375 -1
# 1308 -6.509922 -0.415649 -2.539322  0.604574  10.019492 -1
# 1318 -0.707871 -6.952038 -0.409976  0.627562   9.276474 -1
# 1333 -1.870015 -6.441218  2.003435  0.607794   9.913723 -1
# 1344 -0.009127  6.798041  1.669300  0.618255   9.573967 -1
# 1391  6.959819 -0.562198 -0.494820  0.607897   9.910366 -1
# 1397  1.282120  6.876618  0.261340  0.647716   8.647119 -1
# 1414  0.728155 -6.839914  1.298216  0.625820   9.331810 -1
# 1417  6.913372 -0.994383  0.465278  0.604272  10.029432 -1
# 1429  6.972135  0.207588  0.588423  0.612105   9.773008 -1
# 1440 -3.270287  6.113481  0.964664  0.602374  10.092059 -1
# 1447 -6.814812  0.144125 -1.592972  0.605679   9.983128 -1
# 1454  6.996176  0.174693  0.151679  0.629332   9.220380 -1
# 1459 -6.811578 -0.945454  1.307106  0.614616   9.691497 -1
# 1478 -0.931093  6.934007  0.229370  0.642037   8.822445 -1
# 1493 -1.688957 -6.793049  0.043684  0.608186   9.900894 -1
# 1494 -0.268115  6.982457 -0.416431  0.645503   8.715250 -1
# ################################################## EIF ###################################
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.2164931297302246
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x110136910>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2447f610>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x110181810>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24a18050>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24a1e850>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2610d090>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2612c990>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25d431d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25d54d90>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V2
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V2()
x_lim = 10
y_lim = 7
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  93 1407]]
# ROC AUC : 0.469
# Specificity : 0.0
# Precision : 0.989451476793249
# Recall : 0.938
# f1_score : 0.9630390143737166
# False alarm rate (%) : 6.2000000000000055
# CPU Time (s) : 2.673888921737671
# Memory Consumption (o) : 0
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#              0         1         2         3          4  5
# 1     1.829295  9.508433 -2.498677  0.603131  10.067057 -1
# 16    0.005909 -9.885142  1.511268  0.621274   9.476956 -1
# 25   -9.946004 -0.908495 -0.501630  0.625381   9.345767 -1
# 29   -9.870904 -1.384002 -0.806094  0.618865   9.554319 -1
# 41   -9.953081  0.857258  0.448656  0.623774   9.396996 -1
# 54    0.657777  9.942488  0.845142  0.640460   8.871394 -1
# 57    2.298030 -9.711050  0.643866  0.615177   9.673313 -1
# 112  -9.750444 -0.224812 -2.208689  0.601973  10.105332 -1
# 127  -9.775824 -1.764042  1.149535  0.603682  10.048899 -1
# 129   1.577721 -9.793128  1.267056  0.609340   9.863155 -1
# 138   9.917890 -0.701448  1.069311  0.619679   9.528162 -1
# 152  -9.610806  2.730799  0.418493  0.607495   9.923525 -1
# 181  -0.112325  9.436161 -3.308511  0.610117   9.837777 -1
# 182  -4.009961  8.841708 -2.396752  0.601174  10.131784 -1
# 196   1.390136  9.750207  1.732333  0.623673   9.400231 -1
# 205  -4.043104  8.856174 -2.285059  0.600757  10.145600 -1
# 297   8.783401  2.960806 -3.753065  0.600762  10.145440 -1
# 309  -3.247531  9.097731 -2.585503  0.600643  10.149358 -1
# 329   9.477528 -2.005291 -2.480981  0.603369  10.059215 -1
# 355  -9.722142  1.526559  1.774704  0.602376  10.092005 -1
# 403   1.121159  9.908585 -0.750302  0.629575   9.212710 -1
# 410  -0.229955  9.992620 -0.307664  0.642739   8.800688 -1
# 434   9.753402  2.183980 -0.318412  0.609319   9.863822 -1
# 443  -0.817071  9.960819 -0.338352  0.639551   8.899695 -1
# 446   1.560613  9.513944  2.655062  0.601600  10.117658 -1
# 455   2.408802  9.575057 -1.586174  0.608963   9.875479 -1
# 460  -9.608639  1.436487 -2.368660  0.602275  10.095345 -1
# 531   2.012104  9.725933 -1.165186  0.616525   9.629743 -1
# 532  -2.149274  9.128059 -3.472629  0.600400  10.157409 -1
# 572   9.971153 -0.600798 -0.463833  0.633388   9.092476 -1
# 593  -1.883040 -9.554893 -2.271164  0.600522  10.153377 -1
# 600  -0.635875  9.526963 -2.971975  0.607522   9.922639 -1
# 621  -1.061623 -9.872394 -1.186928  0.616628   9.626411 -1
# 655  -9.918707 -0.199626  1.256745  0.617110   9.610873 -1
# 663   9.952796  0.349236  0.905474  0.627389   9.281958 -1
# 686   9.770398  2.107423  0.313199  0.607364   9.927803 -1
# 701  -0.405313  9.596009  2.784302  0.612712   9.753272 -1
# 706   3.818003  8.879604 -2.564270  0.600768  10.145232 -1
# 712  -1.479266 -9.706124 -1.898141  0.605108  10.001925 -1
# 713  -9.879439 -1.506114  0.358196  0.615498   9.662926 -1
# 759   1.412077  9.413243 -3.065435  0.605602   9.985649 -1
# 778  -9.936876  0.015511 -1.121718  0.617054   9.612683 -1
# 793   9.830363  1.833667  0.040392  0.606572   9.953807 -1
# 794   3.253960  9.334959  1.506748  0.606861   9.944296 -1
# 830   1.258776  9.784468  1.636968  0.622785   9.428593 -1
# 844   0.420740 -9.970715  0.638613  0.638959   8.918126 -1
# 847  -1.038820  9.937395  0.411132  0.638267   8.939713 -1
# 895   1.848322 -9.748610  1.244307  0.612710   9.753339 -1
# 901  -2.202181  9.745734 -0.413592  0.619718   9.526900 -1
# 906   9.956701 -0.121212  0.921633  0.622833   9.427063 -1
# 907   2.495718  9.479139  1.979223  0.613160   9.738700 -1
# 957   9.836799 -0.160897  1.792067  0.604592  10.018908 -1
# 960   1.453583 -9.893768 -0.021232  0.617633   9.593983 -1
# 963   2.158702 -9.760256  0.278228  0.612289   9.767009 -1
# 992   9.651105  1.746106 -1.951229  0.611372   9.796856 -1
# 1010 -9.825643  1.140566  1.468283  0.611800   9.782921 -1
# 1031  9.431170  3.316333  0.234450  0.605344   9.994129 -1
# 1037 -9.570034  2.726482  0.990325  0.606840   9.945008 -1
# 1067 -9.941859  0.873274  0.629948  0.620585   9.499069 -1
# 1073 -9.959000 -0.805606  0.411494  0.623526   9.404931 -1
# 1074  9.940284  1.081797  0.143060  0.620187   9.511846 -1
# 1084  0.243219  9.780854  2.067785  0.626325   9.315738 -1
# 1087 -9.804049 -1.072157 -1.652606  0.609588   9.855031 -1
# 1094 -2.313670 -9.727438  0.154565  0.613697   9.721291 -1
# 1106 -1.007068 -9.813817 -1.635486  0.614472   9.696144 -1
# 1107 -2.911009  9.565830  0.144626  0.608126   9.902866 -1
# 1109 -0.299610  9.497361 -3.116147  0.607775   9.914343 -1
# 1110 -9.857188  1.667173  0.237447  0.619718   9.526896 -1
# 1118  1.038659 -9.920646 -0.708501  0.624837   9.363102 -1
# 1147 -9.700368  1.820648  1.608759  0.600372  10.158351 -1
# 1149  2.808038  9.594921 -0.228950  0.613233   9.736344 -1
# 1181 -4.687305  8.812397 -0.608953  0.600392  10.157685 -1
# 1196  9.975048 -0.229082 -0.667793  0.638670   8.927132 -1
# 1201 -2.286591  9.531722  1.979338  0.607630   9.919101 -1
# 1221  1.021720  9.831994 -1.512610  0.625537   9.340824 -1
# 1250  9.661811 -2.482690 -0.696889  0.607707   9.916562 -1
# 1261 -9.868659  0.526317  1.527271  0.609402   9.861105 -1
# 1266  2.757441  8.897846 -3.636599  0.601209  10.130621 -1
# 1270 -2.518577  9.640290 -0.849457  0.615011   9.678708 -1
# 1289 -9.841709 -0.789261  1.586766  0.608752   9.882360 -1
# 1314 -0.591113 -9.960868  0.657030  0.634941   9.043724 -1
# 1317  0.128621 -9.672535 -2.534863  0.607245   9.931727 -1
# 1343 -9.973872  0.129446 -0.710716  0.625402   9.345101 -1
# 1346  0.634845  9.422567 -3.288191  0.611221   9.801774 -1
# 1367 -9.819865 -1.699468  0.825874  0.604241  10.030470 -1
# 1376  9.977974 -0.487804 -0.449538  0.641536   8.837991 -1
# 1416  9.715928  1.936452  1.360481  0.605616   9.985200 -1
# 1449 -1.752501  9.475083 -2.674238  0.610479   9.825962 -1
# 1454 -9.906216  0.339035 -1.323605  0.616253   9.638549 -1
# 1467  9.771008  2.005659  0.710442  0.610736   9.817576 -1
# 1473 -1.295727  9.673699 -2.177299  0.624956   9.359324 -1
# 1474  1.983135  9.764811  0.845957  0.623392   9.409214 -1
# 1486  2.524703  9.673326  0.229419  0.622568   9.435544 -1
# ################################################## EIF ###################################
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.20624828338623047
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a25d25490>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a23ab5b50>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25b730d0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2441c690>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a243f7890>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24744890>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2442a7d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24457150>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24ab9110>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V3_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V3_2_0()
x_lim = 17
y_lim = 12
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  28 1472]]
# ROC AUC : 0.49066666666666664
# Specificity : 0.0
# Precision : 0.9899125756556826
# Recall : 0.9813333333333333
# f1_score : 0.9856042852360228
# False alarm rate (%) : 1.866666666666672
# CPU Time (s) : 2.502951145172119
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2         3          4  5
# 42   -0.712123  8.929825 -0.866668  0.610747   9.817221 -1
# 193  -0.309569 -8.980890  0.497785  0.612689   9.754030 -1
# 206   8.924058  1.111947 -0.353211  0.602282  10.095118 -1
# 262   8.942872  1.001114 -0.151043  0.605150  10.000539 -1
# 276  -8.985354 -0.313438 -0.406409  0.602744  10.079841 -1
# 292   0.934998  8.937343  0.499684  0.605296   9.995725 -1
# 326   8.937051 -0.542568  0.913645  0.610687   9.819182 -1
# 344   0.255783  8.970319 -0.684068  0.609861   9.846123 -1
# 432  -0.098192 -8.960818 -0.833126  0.608095   9.903882 -1
# 475   8.974488 -0.022628  0.676799  0.613418   9.730342 -1
# 520   8.978609  0.396594 -0.476760  0.615014   9.678601 -1
# 543  -0.453674 -8.986830 -0.176239  0.611804   9.782811 -1
# 630  -0.696895 -8.972092 -0.126103  0.612555   9.758365 -1
# 708   8.971235  0.574198 -0.432721  0.609441   9.859843 -1
# 722  -8.999556  0.066708 -0.059441  0.602355  10.092693 -1
# 829   0.784848  8.940130  0.676828  0.606699   9.949632 -1
# 840   8.930852  0.054568  1.112159  0.611126   9.804881 -1
# 919  -1.112658  8.841468 -1.261128  0.603155  10.066275 -1
# 925  -0.978112  8.944219 -0.210320  0.613746   9.719689 -1
# 989   0.537618 -8.982162  0.178125  0.614749   9.687196 -1
# 1112  0.250684 -8.986623 -0.421629  0.616339   9.635767 -1
# 1120 -1.192261  8.900150 -0.604849  0.603680  10.048941 -1
# 1134  8.991666  0.082244  0.378380  0.617250   9.606334 -1
# 1160  0.849320  8.959689 -0.051298  0.610231   9.834061 -1
# 1257  0.700480  8.910670 -1.053227  0.605040  10.004132 -1
# 1330  8.934227  1.025135  0.358740  0.605503   9.988925 -1
# 1401 -1.154672  8.888895 -0.808873  0.603227  10.063886 -1
# 1493  0.704076  8.942999  0.725977  0.606988   9.940133 -1
# ################################################## EIF ###################################
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.17939519882202148
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a25e7c650>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25c5a210>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2684f110>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2473c350>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25cf19d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a249c0ed0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2446d450>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2680a650>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a243ed510>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V3_3_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V3_3_0()
x_lim = 17
y_lim = 12
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  39 1461]]
# ROC AUC : 0.487
# Specificity : 0.0
# Precision : 0.9898373983739838
# Recall : 0.974
# f1_score : 0.9818548387096774
# False alarm rate (%) : 2.6000000000000023
# CPU Time (s) : 2.488467216491699
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by IForest
#              0         1         2         3          4  5
# 15   -8.949386 -0.918312 -0.255333  0.613678   9.721895 -1
# 142   8.834875 -1.497737  0.837719  0.601350  10.125957 -1
# 207  -8.915634 -0.012284  1.229354  0.610665   9.819906 -1
# 264  -8.925167  0.057601  1.156756  0.615139   9.674572 -1
# 279   8.916857  1.206792  0.182541  0.612045   9.774948 -1
# 357   8.940730  0.997355  0.261980  0.612703   9.753554 -1
# 376  -8.995929  0.269346 -0.026609  0.622168   9.448349 -1
# 394  -8.919292 -1.094627  0.498019  0.609659   9.852713 -1
# 436  -8.937773  0.986780  0.377452  0.616683   9.624630 -1
# 480   8.972270 -0.658184  0.255259  0.613434   9.729826 -1
# 502   8.910998  0.612648  1.103985  0.605565   9.986892 -1
# 537   0.266276 -8.990391  0.319324  0.604910  10.008436 -1
# 559  -0.758370 -8.965938  0.191900  0.607402   9.926582 -1
# 568   8.979579 -0.444229  0.412101  0.620117   9.514091 -1
# 674  -0.355856 -8.970978  0.628427  0.600974  10.138408 -1
# 689   8.849131  0.096364  1.638168  0.603974  10.039254 -1
# 794   8.942241  0.798368  0.631613  0.605837   9.977926 -1
# 831  -8.965157 -0.094134  0.785555  0.621437   9.471736 -1
# 914   8.963713 -0.085955  0.802778  0.611173   9.803340 -1
# 920  -8.928037 -0.754509 -0.849041  0.611278   9.799934 -1
# 930   8.878297  0.867556 -1.192971  0.600541  10.152743 -1
# 1011  8.945923  0.808859 -0.562329  0.614409   9.698213 -1
# 1036 -8.887917 -0.521764  1.316319  0.606206   9.965818 -1
# 1046  1.003437 -8.921311 -0.635079  0.600589  10.151156 -1
# 1049  8.928852 -0.773863 -0.822645  0.610871   9.813183 -1
# 1057  8.889702  1.330103 -0.451688  0.614641   9.690699 -1
# 1094 -8.923223  0.384697 -1.108200  0.610078   9.839056 -1
# 1135 -8.985525  0.487534 -0.150480  0.623115   9.418046 -1
# 1170  0.752321 -8.957432  0.445457  0.603610  10.051272 -1
# 1183  8.804023 -0.012020  1.867897  0.600198  10.164134 -1
# 1215 -8.914472 -0.681105 -1.033581  0.602528  10.086977 -1
# 1225  8.976224 -0.584191  0.293464  0.619149   9.545199 -1
# 1230 -8.984756 -0.166325  0.496483  0.621877   9.457667 -1
# 1270 -8.904955 -0.251510  1.280048  0.609699   9.851433 -1
# 1278 -8.975810 -0.157138 -0.640425  0.622836   9.426983 -1
# 1285  8.997073  0.215624  0.078645  0.627548   9.276903 -1
# 1390  8.939858 -0.985777  0.327379  0.609371   9.862121 -1
# 1413  0.018717 -8.952504 -0.923210  0.606076   9.970080 -1
# 1442 -8.818302 -0.333071  1.768225  0.601409  10.123999 -1
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ################################################## EIF ###################################
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.18994784355163574
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a27082c90>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24458750>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a27f585d0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27c80290>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25f76550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a260b9210>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24642690>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a24677e90>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a246ada90>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V3_4_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V3_4_0()
x_lim = 17
y_lim = 12
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  27 1473]]
# ROC AUC : 0.491
# Specificity : 0.0
# Precision : 0.9899193548387096
# Recall : 0.982
# f1_score : 0.9859437751004014
# False alarm rate (%) : 1.8000000000000016
# CPU Time (s) : 2.347928762435913
# Memory Consumption (o) : 0
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#              0         1         2         3          4  5
# 18    8.971310 -0.621801  0.359122  0.614307   9.701521 -1
# 55    0.655085  8.975019  0.141083  0.608979   9.874950 -1
# 139   0.293970  8.995056  0.050448  0.611394   9.796146 -1
# 162   0.652872  8.971526  0.292380  0.609169   9.868746 -1
# 229  -1.008760  8.913179 -0.733236  0.605172   9.999800 -1
# 283   0.971305  8.943978 -0.248659  0.604071  10.036048 -1
# 319   8.945037  0.605784 -0.786985  0.605811   9.978793 -1
# 339   8.961229  0.795672  0.251568  0.620967   9.486814 -1
# 358   0.569523  8.940734  0.859602  0.602113  10.100691 -1
# 546   8.952022  0.509852 -0.775467  0.610664   9.819942 -1
# 582   8.950527  0.879081 -0.339520  0.614714   9.688309 -1
# 688  -8.935375 -0.506391 -0.950071  0.605059  10.003513 -1
# 849   8.921617  0.775623  0.896187  0.601188  10.131303 -1
# 898  -8.974391  0.656758 -0.170200  0.602880  10.075359 -1
# 946   8.961614 -0.708890  0.432387  0.607547   9.921812 -1
# 1003 -8.979821 -0.274409  0.536211  0.603084  10.068605 -1
# 1119 -0.529748  8.936726 -0.924278  0.605807   9.978928 -1
# 1136  8.955901  0.005781  0.889833  0.617608   9.594791 -1
# 1152 -0.102803  8.992946 -0.341096  0.610153   9.836584 -1
# 1163 -0.209294  8.969929 -0.704672  0.610948   9.810665 -1
# 1242 -0.179641  8.965370  0.768026  0.614758   9.686907 -1
# 1247 -0.653004  8.966664 -0.415348  0.616167   9.641327 -1
# 1262 -0.906079  8.913522 -0.853311  0.603523  10.054141 -1
# 1387  8.931101  0.818822  0.751638  0.600737  10.146252 -1
# 1426 -0.156048  8.956918 -0.865604  0.603006  10.071185 -1
# 1430 -0.185597 -8.996562 -0.165592  0.602289  10.094882 -1
# 1476 -8.944167 -0.792249 -0.611731  0.605242   9.997516 -1
# ################################################## EIF ###################################
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.21588468551635742
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a270df810>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25e33250>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a26f36310>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27f0c3d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a267be810>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25f3ed90>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27f31d50>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a27edd890>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a26f3fe10>]],
#        dtype=object))

# %% [markdown]
# ### Dataset ThreeD_V4_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.ThreeD_V4_2_0()
x_lim = 17
y_lim = 12
z_lim = 4
#X_brut.describe()
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#print(X_brut)
print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, z_lim = z_lim, n_dimensions=3)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [  60 1440]]
# ROC AUC : 0.48
# Specificity : 0.0
# Precision : 0.9896907216494846
# Recall : 0.96
# f1_score : 0.9746192893401014
# False alarm rate (%) : 4.0000000000000036
# CPU Time (s) : 2.765303134918213
# Memory Consumption (o) : 0
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#              0         1          2         3          4  5
# 31    9.999108 -0.126526  -0.042784  0.645775   8.706850 -1
# 32    9.833429  0.879924   1.590411  0.617230   9.606991 -1
# 57    0.160971  0.300098  -9.994200  0.603622  10.050864 -1
# 64   -0.260919 -9.970653  -0.719726  0.615172   9.673497 -1
# 70   -0.598278 -9.955550  -0.727386  0.605513   9.988583 -1
# 76   -0.058523  0.039252  -9.999752  0.612082   9.773753 -1
# 85    9.746707  2.236036   0.042892  0.611837   9.781733 -1
# 102  -9.987263  0.479618   0.156676  0.615000   9.679059 -1
# 109  -9.932264  0.400228   1.090849  0.600744  10.146036 -1
# 143   9.892638 -1.218180  -0.807310  0.632335   9.125622 -1
# 187  -0.609856  9.896397  -1.299771  0.601258  10.128992 -1
# 215  -1.777884 -9.792740   0.970243  0.608755   9.882254 -1
# 219  -2.208406 -9.729722   0.674873  0.609047   9.872725 -1
# 234  -0.004608  0.230575  -9.997340  0.603467  10.055961 -1
# 271   9.754248 -2.067256  -0.762293  0.616106   9.643293 -1
# 276   0.018874 -9.980821   0.618757  0.622196   9.447443 -1
# 305   9.585263 -2.694707   0.928060  0.602182  10.098422 -1
# 309   0.304232 -9.980544   0.544222  0.617901   9.585374 -1
# 349  -0.831538  9.923389   0.913731  0.606470   9.957160 -1
# 367   9.896877 -1.230435   0.733390  0.636292   9.001404 -1
# 381   0.026434  0.008440  -9.999961  0.613222   9.736687 -1
# 409   9.703536  2.287862   0.779150  0.610088   9.838708 -1
# 432  -0.883451 -9.959614   0.160009  0.609154   9.869213 -1
# 445   9.783623 -1.995238  -0.547483  0.619783   9.524815 -1
# 461   0.897242 -9.795581   1.800431  0.600054  10.168912 -1
# 470   0.036541 -0.039880  -9.999854  0.613594   9.724613 -1
# 535   9.926503  1.210177   0.003808  0.629283   9.221928 -1
# 569   0.001515  0.001879 -10.000000  0.614211   9.704613 -1
# 607   0.157108 -0.381776  -9.991475  0.602133  10.100031 -1
# 646  -1.949925 -9.806871  -0.151875  0.603951  10.040031 -1
# 665  -0.653290 -9.897862  -1.267100  0.600985  10.138039 -1
# 703   9.644462 -2.465338   0.952086  0.602074  10.101980 -1
# 731  -9.983146 -0.186435   0.549573  0.611045   9.807509 -1
# 772  -9.952152  0.483041   0.849317  0.603779  10.045699 -1
# 792   9.736252  0.615537   2.196934  0.605183   9.999456 -1
# 799  -1.091473 -9.904612  -0.841038  0.600191  10.164345 -1
# 804   9.737221  2.167753  -0.698124  0.611531   9.791692 -1
# 818   9.703525 -1.861466  -1.541604  0.610028   9.840686 -1
# 831   9.813918  1.153500   1.535072  0.611001   9.808950 -1
# 849   9.987902  0.491734   0.001981  0.637499   8.963661 -1
# 866   9.977200  0.157160  -0.656339  0.633987   9.073675 -1
# 879   0.755280  9.954423  -0.582243  0.612261   9.767927 -1
# 947   0.401256  9.894052   1.395252  0.601518  10.120372 -1
# 948  -0.024318 -0.013963  -9.999961  0.613594   9.724613 -1
# 961  -0.078576  0.177832  -9.998110  0.606405   9.959270 -1
# 1034 -0.675269  9.940621   0.853268  0.612149   9.771580 -1
# 1050  9.832833  0.086993   1.818745  0.616554   9.628826 -1
# 1144 -0.689970 -9.893203   1.283930  0.600727  10.146572 -1
# 1163  0.425376 -9.960149  -0.783895  0.607742   9.915439 -1
# 1206  9.621303 -2.699579  -0.377887  0.602803  10.077911 -1
# 1299  9.698519 -2.093511  -1.247372  0.612996   9.744044 -1
# 1301  9.772929  1.921619  -0.892883  0.611375   9.796765 -1
# 1315  9.617308 -2.724941   0.286482  0.604332  10.027455 -1
# 1338  0.881819 -9.935379   0.714590  0.603936  10.040520 -1
# 1364  0.582334 -9.928533   1.041688  0.603080  10.068758 -1
# 1394 -1.912300 -9.798520  -0.576296  0.604435  10.024055 -1
# 1408 -0.312679 -9.994342  -0.123922  0.619983   9.518373 -1
# 1440  9.927217 -1.201838  -0.077062  0.644326   8.751584 -1
# 1459  9.817966  1.036795  -1.591415  0.615365   9.667253 -1
# 1496  9.722359 -1.851521  -1.430944  0.609545   9.856455 -1
# ################################################## EIF ###################################
# Confusion matrice
# [[   0   15]
#  [   0 1500]]
# ROC AUC : 0.5
# Specificity : 0.0
# Precision : 0.9900990099009901
# Recall : 1.0
# f1_score : 0.9950248756218906
# False alarm rate (%) : 0.0
# CPU Time (s) : 0.21590781211853027
# Memory Consumption (o) : 0
# ****************************************************************
# Abnormal predicted data by EIF
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []
# ../../../../../experiments/trainning_parametors.py:108: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 1440x1080 with 9 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1101cb490>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a242cf4d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a287d1950>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a287b4650>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a2876f310>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a28f76690>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x1a28f94350>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a7a7d0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1a25fddf10>]],
#        dtype=object))
