# %% [markdown]
# # Trainning with normal data only

# %% [markdown]
# ## Test with 2 dimension dataset

# %%
import sys
sys.path.append('../../../../../')
from datasets import datasets as datat
dts = datat.synthetic_datasets(path_top="../../../../../")

util = datat.utilitaries()

from metrics import useful_infos as ue

from experiments import trainning_parametors
t_parametors = trainning_parametors.functions_train_parametors()

# %% [markdown]
# ## Generals settings

# %%
dts = datat.synthetic_datasets(path_top="../../../../../")
max_samples = 256
n_trees = 100
threshold = 0.6
min_sample_size = 5
sample_size_step = 5

# %% [markdown]
# ## Executions

# %% [markdown]
# ### Dataset TwoD_V1_0
# #### Conclusion on this dataset :
# IForest better than EIF

# %%
from math import sqrt

sqrt(1515)
# Out:
# 38.92300091205713

# %%
38**2
# Out:
# 1444

# %%
1515 - 1444 
#MUT_19052020_0227:
#Adding the threshold on the distribution
# Out:
# 71

# %%
# Load the dataset
x_lim = 10
y_lim = 7

X_brut, y_transform, full_dataset = dts.TwoD_V1_0()

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
# Out:
# ################################################## IFOREST ###################################
# Confusion matrice
# [[   0   15]
#  [ 211 1289]]
# ROC AUC : 0.42966666666666664
# Specificity : 0.0
# Precision : 0.9884969325153374
# Recall : 0.8593333333333333
# f1_score : 0.9194008559201141
# False alarm rate (%) : 14.066666666666672
# CPU Time (s) : 1.1504442691802979
# Memory Consumption (o) : 11722752
# ****************************************************************
# ../../../../../experiments/trainning_parametors.py:66: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Abnormal predicted data by IForest
#              0         1         2          3  4
# 2     0.203131  6.482506  0.632041   9.134868 -1
# 5     3.106334  6.076085  0.629538   9.213884 -1
# 19    5.589001  4.085129  0.606567   9.953972 -1
# 27    0.455350  6.459653  0.623025   9.420921 -1
# ...

# %% [markdown]
# ### Dataset TwoD_V1_1
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V1_1()
x_lim = 10
y_lim = 7

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V2
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V2()
x_lim = 10
y_lim = 7

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V3_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_0_0()
x_lim = 12
y_lim = 9

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V3_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_1_0()
x_lim = 12
y_lim = 9

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V3_2_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V3_2_0()
x_lim = 12
y_lim = 9

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset 4.2.0
# #### Conclusion on this dataset :
# EIF is better than IForest

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V4_2_0()
x_lim = 17
y_lim = 12

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V5_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_0_0()
x_lim = 30
y_lim = 20

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V5_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V5_1_0()
x_lim = 40
y_lim = 30

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V6_0_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_0_0()
x_lim = 30
y_lim = 20

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %% [markdown]
# ### Dataset TwoD_V6_1_0
# #### Conclusion on this dataset :

# %%
# Load the dataset
X_brut, y_transform, full_dataset = dts.TwoD_V6_1_0()
x_lim = 40
y_lim = 30

X_normal,Y_normal, X_abnormal, Y_abnormal = util.normals_abnormals_XY(
    dataset=full_dataset, outlier_label=ue._OUTLIER_PREDICTION_LABEL)

print("################################################## IFOREST ###################################")
t_parametors.execute_IForest(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)
print("################################################## EIF ###################################")
t_parametors.execute_eif(X_brut=X_brut, max_samples=max_samples, n_trees=n_trees, threshold=threshold, 
                y_transform=y_transform, x_lim=x_lim, y_lim=y_lim, X_train=X_normal)

# %%
n = 256
2.0*(np.log(n-1)+0.5772156649) - (2.0*(n-1.)/(n*1.0))

# %%
50**2
