# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from mpl_toolkits import mplot3d

# %% [markdown]
# ## Paramètres de jeu de données

# %%
dimension_number = 4
radius = 7
param_y_normal_data = 1
param_y_abnormal_data = 0
contamination = 1/100 # 1%
file_name = "synthetic_"+str(dimension_number)+"D_data_"+str(datetime.now())
#full_file_path = str(datetime.now().date())+"/"+file_name+".csv"
full_file_path = file_name+".csv"

# %% [markdown]
# ## Normal dataset generation

# %% [markdown]
# ### A supprimer
# #Normal “continuous uniform” distribution dataset https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.random_sample.html
# mu = 0 #mean
# sigma = 1 #Standard deviation
# size = 750 #number of samples
# y_n_dataset  = []
# x1_n_dataset = []
# x2_n_dataset = []
# x3_n_dataset = []
# i = 0
# while i<size:
#     #longitude entre 0 et 2pi
#     longitude = (2*np.pi-0) * np.random.random_sample() + 0
#     #latitude entre -pi/2 et pi/2
#     latitude = (np.pi/2 --np.pi/2) * np.random.random_sample() + -np.pi/2
#
#     x1 = radius * np.cos(latitude) * np.cos(longitude)
#     x1_n_dataset.append(x1)
#     x2 = radius * np.cos(latitude) * np.sin(longitude)
#     x2_n_dataset.append(x2)
#     x3 = radius * np.sin(latitude)
#     x3_n_dataset.append(x3)
#     x4 = np.sqrt(radius**2 - x1**2 - X)
#     y_n_dataset.append(param_y_normal_data)
#     i = i + 1
#
# n_data_array = {'0': x1_n_dataset, '1':x2_n_dataset, '2':x3_n_dataset, 'is_normal': y_n_dataset}
# n_dataset = pd.DataFrame(n_data_array, columns=['0', '1', '2', 'is_normal'])
# #n_dataset

# %%
#### A supprimer plus tard
#Normal “continuous uniform” distribution dataset https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.random_sample.html
mu = 0 #mean
sigma = 1 #Standard deviation
size = 1000 #number of samples
y_n_dataset  = []
x1_n_dataset = []
x2_n_dataset = []
x3_n_dataset = []
x4_n_dataset = []
i = 0
while i<size:
    x1 = radius*2 * np.random.random_sample() + -radius
    x2 = radius*2 * np.random.random_sample() + -radius
    x3 = radius*2 * np.random.random_sample() + -radius
    x4 = np.sqrt(7**2 - x1**2 - x2**2 - x3**2)
    #print("x1 ="+str(x1)+" x2 = "+str(x2)+" x3 = "+str(x3))
    #found = False
    #while not found:
    #    x4 = radius*2 * np.random.random_sample() + -radius
    #    distance = np.sqrt(x1**2 + x2**2 + x3**2 + x4**2)
    #    if distance == radius:
    #        found = True
    print("x1 ="+str(x1)+" x2 = "+str(x2)+" x3 = "+str(x3)+" x4 = "+str(x4))
    x1_n_dataset.append(x1)
    x2_n_dataset.append(x2)
    x3_n_dataset.append(x3)
    x4_n_dataset.append(x4)
    y_n_dataset.append(param_y_normal_data)
    i = i + 1
n_data_array = {'0': x1_n_dataset, '1':x2_n_dataset, '2':x3_n_dataset, '3':x4_n_dataset, 'is_normal': y_n_dataset}
n_dataset = pd.DataFrame(n_data_array, columns=['0', '1', '2', '3', 'is_normal'])
n_dataset
# Out:
# x1 =-4.818824372537216 x2 = -0.8299791268930843 x3 = 5.284547968669928 x4 = nan
# x1 =6.071061822245095 x2 = 3.4814498188435774 x3 = 5.4894593638519265 x4 = nan
# x1 =-1.7982806430895621 x2 = 4.685932890402835 x3 = 4.029690106174918 x4 = 2.7513301007923965
# x1 =1.0257699266621163 x2 = 2.1949924492028714 x3 = -4.353432860600192 x4 = 4.917054660438951
# x1 =-1.4789763413017063 x2 = -4.597574880509464 x3 = 3.64041987928276 x4 = 3.5245251173031953
# x1 =-5.081659522018718 x2 = -0.4865147331029629 x3 = 5.747242540827774 x4 = nan
# x1 =0.95145501680115 x2 = 0.765532421167717 x3 = -5.477030917745916 x4 = 4.1845938619178265
# x1 =-0.5423165006149935 x2 = -6.404214300395993 x3 = 3.2777756671627802 x4 = nan
# x1 =-6.974960828194359 x2 = 5.003779174881492 x3 = -1.5457878481684606 x4 = nan
# /Users/thesard/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
#            0         1         2         3  is_normal
# 0  -4.818824 -0.829979  5.284548       NaN          1
# 1   6.071062  3.481450  5.489459       NaN          1
# 2  -1.798281  4.685933  4.029690  2.751330          1
# 3   2.566705 -2.252940  4.534009  4.096224          1
# 4   2.752740 -5.798640 -1.196732  2.523098          1
# 5  -1.909996  3.473788 -1.021235  5.678186          1
# 6  -5.672155 -2.749268 -3.608750       NaN          1
# 7  -5.170809  4.518281 -3.836828       NaN          1
# 8  -1.847437 -2.573559 -2.110588  5.874452          1
# 9   2.664980  3.651038 -4.848798  2.248769          1
# 10  1.426794  4.973197 -3.322281  3.345746          1
# 11  1.446809 -5.384512 -0.131417  4.230426          1
# 12 -2.384324  3.399575 -1.683804  5.377982          1
# 13  1.166468  0.223854 -3.219058  6.101385          1
# 14  0.973590 -0.730576 -6.990028       NaN          1
# 15  0.319055  5.562466 -3.780439  1.914538          1
# 16  4.388751  6.046137 -2.787845       NaN          1
# 17  0.769345 -5.411149  1.802256  3.984902          1
# 18  6.758138  2.224973 -4.965695       NaN          1
# 19 -5.707683 -5.628844 -2.302649       NaN          1
# 20 -3.620410  2.220334 -6.026682       NaN          1
# 21 -4.152460  3.430310  4.356369  1.006032          1
# 22  4.180632  1.976200  5.401208       NaN          1
# 23  5.614957 -2.576212  1.808764  2.750229          1
# 24 -2.337729 -2.050784  5.952307  1.974679          1
# 25  5.183745  0.425575  2.546344  3.932404          1
# 26  5.223779  2.522712 -5.397774       NaN          1
# 27 -2.205613 -0.652358 -6.757358       NaN          1
# 28  4.619970  3.798045  0.074839  3.636637          1
# 29  0.788034  0.408716 -3.209772  6.157054          1
# ..       ...       ...       ...       ...        ...
# 70 -0.261761  2.953262  1.593020  6.137753          1
# 71  2.097142 -6.927162  5.841902       NaN          1
# 72 -5.870456  2.186259 -3.084828  0.491787          1
# 73 -4.263393  6.571138 -4.254108       NaN          1
# 74 -3.277057  2.571725  1.742042  5.349057          1
# 75  5.161571  0.103106  1.262099  4.555729          1
# 76 -4.309996 -4.468257 -2.973913  1.270611          1
# 77 -1.846504  0.104087 -1.857925  6.490586          1
# 78 -6.035672  1.445254 -1.128883  3.034391          1
# 79  2.500015  0.433177  6.388030  1.324899          1
# 80 -5.430421 -5.990024  1.398587       NaN          1
# 81 -4.660655  4.187204 -1.591711  2.685531          1
# 82  4.529948  1.075447  1.962966  4.844559          1
# 83 -3.702325 -0.995420  0.966742  5.776447          1
# 84  4.330262 -3.310854 -3.617505  2.490126          1
# 85  5.176951  0.912092  6.471044       NaN          1
# 86 -1.596321  5.947126  5.051861       NaN          1
# 87  1.820582  4.535432 -2.969362  4.037107          1
# 88 -6.096515  4.209542  6.496655       NaN          1
# 89 -2.915459  5.663035  5.127909       NaN          1
# 90 -5.935867  4.918563  1.547876       NaN          1
# 91 -3.119274 -1.052619 -4.971781  3.666540          1
# 92  6.410897  0.262846 -3.128129       NaN          1
# 93 -3.536277 -3.831662  1.458012  4.437038          1
# 94  1.025770  2.194992 -4.353433  4.917055          1
# 95 -1.478976 -4.597575  3.640420  3.524525          1
# 96 -5.081660 -0.486515  5.747243       NaN          1
# 97  0.951455  0.765532 -5.477031  4.184594          1
# 98 -0.542317 -6.404214  3.277776       NaN          1
# 99 -6.974961  5.003779 -1.545788       NaN          1
#
# [100 rows x 5 columns]

# %%
# Vérification
i = 10
np.sqrt(x1_n_dataset[i]**2 + x2_n_dataset[i]**2 + x3_n_dataset[i]**2 + x4_n_dataset[i]**2) == radius
# Out:
# True

# %%
# %matplotlib inline
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-7.,7.)
ax.set_ylim(-10.,10.)
ax.set_zlim(-4.,4.)

ax.scatter3D(n_dataset['0'], n_dataset['1'], n_dataset['2']);
ax.scatter3D(n_dataset['0'], n_dataset['2'], n_dataset['3']);
ax.scatter3D(n_dataset['1'], n_dataset['2'], n_dataset['3']);
ax.scatter3D(0, 0, 0, c="r");

# %% [markdown]
# ## Abnormal gaussian dataset generation

# %%
#Abnormal gaussian dataset
mu_a = 0 #mean
sigma_a = 0.5 #Standard deviation
size_a = int(size*contamination) #size of samples
y_a_dataset  = []
x1_a_dataset = []
x2_a_dataset = []
x3_a_dataset = []
i = 0
while i<size_a:
    y_a_dataset.append(param_y_abnormal_data)
    i = i + 1
x1_a_dataset = np.random.normal(mu_a, sigma_a, size_a)
x2_a_dataset = np.random.normal(mu_a, sigma_a, size_a)
x3_a_dataset = np.random.normal(mu_a, sigma_a, size_a)
a_data_array = {'0': x1_a_dataset, '1':x2_a_dataset, '2':x3_a_dataset, 'is_normal': y_a_dataset}
a_dataset = pd.DataFrame(a_data_array, columns=['0', '1', '2', 'is_normal'])
#a_dataset

# %%
# Vérification
j = 2
distance = np.sqrt(x1_a_dataset[j]**2 + x2_a_dataset[j]**2 + x3_a_dataset[j]**2)
distance
# Out:
# 0.8363056751431595

# %%
# %matplotlib inline
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-7.,7.)
ax.set_ylim(-10.,10.)
ax.set_zlim(-4.,4.)

ax.scatter3D(n_dataset['0'], n_dataset['1'], n_dataset['2'], c="g");
ax.scatter3D(0, 0, 0, c="r");
ax.scatter3D(a_dataset['0'], a_dataset['1'], a_dataset['2'], c="b");

# %% [markdown]
# ## Génération du jeu de données complet

# %%
dataset = pd.concat([n_dataset, a_dataset], ignore_index=True, sort=False)
dataset
# Out:
#             0         1         2  is_normal
# 0   -2.991590  5.665822 -2.819371          1
# 1    3.283717  6.160134 -0.519576          1
# 2    3.154118 -0.111830 -6.248122          1
# 3    4.469324 -4.822999 -2.400796          1
# 4    3.729044  2.648538 -5.299007          1
# 5   -1.627384 -5.926299 -3.351209          1
# 6    3.664377  0.770466 -5.914282          1
# 7   -3.115490 -2.914436  5.549756          1
# 8   -6.225445  2.206223 -2.318709          1
# 9    1.252563 -3.529152  5.914066          1
# 10   3.118507  2.544746  5.727057          1
# 11  -6.459532 -1.973039  1.838905          1
# 12  -3.234090  3.394305 -5.198014          1
# 13   0.417403  3.441609 -6.081209          1
# 14  -5.968466  3.496532 -1.073165          1
# 15  -2.089312 -5.792320  3.329235          1
# 16   2.933273  2.182421  5.969334          1
# 17   6.460407 -2.685235 -0.229452          1
# 18  -3.014200 -0.958998  6.244591          1
# 19  -3.582503  2.883177 -5.277590          1
# 20   4.338270 -5.456347  0.638505          1
# 21  -5.386959 -2.077619  3.957799          1
# 22   0.018292  3.550589 -6.032660          1
# 23   2.777216  6.368257 -0.855787          1
# 24   2.131385 -2.185114 -6.299403          1
# 25   4.020461  4.963065  2.864241          1
# 26   3.443361 -3.250914  5.155078          1
# 27  -4.395912  2.171534 -4.996038          1
# 28  -4.944050 -3.982134 -2.949404          1
# 29  -0.109117 -0.020357 -6.999120          1
# ..        ...       ...       ...        ...
# 727  0.117946 -0.317794 -6.991788          1
# 728 -1.066131 -3.353809  6.051060          1
# 729  0.435842  4.707309 -5.162488          1
# 730  2.245718  4.161500  5.161266          1
# 731 -4.609998 -2.753574  4.490629          1
# 732  0.663087 -6.963743 -0.258075          1
# 733  6.261058  1.222816 -2.881645          1
# 734  6.864439  0.177135  1.359446          1
# 735 -4.489193 -4.118601 -3.447357          1
# 736 -0.086642 -0.236620 -6.995463          1
# 737  3.309508 -4.674621 -4.024311          1
# 738 -3.236524 -5.435519  2.996672          1
# 739 -4.270506  5.480387  0.853309          1
# 740  0.421068  1.723843  6.771342          1
# 741  0.273393  6.588416  2.349049          1
# 742 -5.585221  2.789290  3.166255          1
# 743  6.726626  1.441844  1.293670          1
# 744 -0.502208  3.961726 -5.749131          1
# 745  3.843676  4.231736 -4.039624          1
# 746 -1.614277 -6.226452 -2.761413          1
# 747 -3.232635 -0.431466  6.193860          1
# 748  0.125704  6.689432 -2.058082          1
# 749  5.836812  2.959179 -2.484933          1
# 750  1.122824 -0.356093  0.120933          0
# 751  0.276304 -0.525181 -0.574884          0
# 752  0.465400  0.435198 -0.541676          0
# 753  0.589247  0.388794  0.107955          0
# 754 -0.897986 -0.128752  0.693429          0
# 755  1.193316  0.468545 -0.333910          0
# 756  1.102181  0.648167 -0.293066          0
#
# [757 rows x 4 columns]

# %%
dataset.describe()
# Out:
#                 0           1           2   is_normal
# count  757.000000  757.000000  757.000000  757.000000
# mean    -0.039409   -0.006554    0.052346    0.990753
# std      3.584744    3.408630    4.914092    0.095779
# min     -6.914687   -6.975871   -6.999958    0.000000
# 25%     -2.750968   -2.200805   -4.628255    1.000000
# 50%     -0.050488   -0.091029   -0.258075    1.000000
# 75%      2.655158    2.302402    5.118321    1.000000
# max      6.988704    6.997819    6.999999    1.000000

# %% [markdown]
# ## Créé le fichier .csv du jeu de données

# %%
dataset.to_csv(full_file_path, index=None, header=True)
