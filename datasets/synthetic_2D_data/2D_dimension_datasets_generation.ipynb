# %% [markdown]
# # 2-Dimensions synthetics datasets generation

# %%
# %matplotlib inline
#%matplotlib notebook
#calling it a second time may prevent some graphics errors
#%matplotlib notebook  

import sys
sys.path.append('../')
import datasets_generator as dg
data_gene = dg.synthetic_datasets(path_top="../")

# %% [markdown]
# ## Generals parameters

# %%
n_dimension = 2
n_size = 1500 #number of normal samples
contamination = 1/100 # 1%
size_a = int(n_size*contamination) #size of abnormal samples

# %% [markdown]
# ## Version 1.0.0

# %%
version = "1.0.0"

#Normal data
n_min_circle = 2 #Rayon
n_max_circle = 7 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 2 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 11
y_lim = 8
z_lim = 0.0

min_value = -10
max_value = 10
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 5 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 0 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -10 et 10,
#  - y entre -10 et 10,
#  - taille = 1500,
#  - distance euclidienne entre 2 et 7 (Grand cercle de rayon 7 et petit cercle de rayon 2)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -10 et 10,
#  - y entre -10 et 10,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 2 (Grand cercle de rayon 2 et petit cercle de rayon 0.0)
# ...
# Output()
# ...
# Output()
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V1.0.0_11_8_0_2020-08-26 15:59:24.001177

# %% [markdown]
# ## Version 2.0.0

# %%
version = "2.0.0"

#Normal data
n_min_circle = 5 #Rayon
n_max_circle = 7 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 2 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 11
y_lim = 8
z_lim = 0.0

min_value = -10
max_value = 10
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 2 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 3 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -10 et 10,
#  - y entre -10 et 10,
#  - taille = 1500,
#  - distance euclidienne entre 5 et 7 (Grand cercle de rayon 7 et petit cercle de rayon 5)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -10 et 10,
#  - y entre -10 et 10,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 2 (Grand cercle de rayon 2 et petit cercle de rayon 0.0)
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V2.0.0_11_8_0_2020-08-28 01:36:23.477981

# %% [markdown]
# ## Version 3.0.0

# %%
version = "3.0.0"

#Normal data
n_min_circle = 9 #Rayon
n_max_circle = 10 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 4 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 4 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 9 et 10 (Grand cercle de rayon 10 et petit cercle de rayon 9)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 4 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 4)
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V3.0.0_16_11_0_2020-08-28 01:53:29.858404

# %% [markdown]
# ## Version 3.1.0

# %%
version = "3.1.0"

#Normal data
n_min_circle = 7 #Rayon
n_max_circle = 9 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 2 #Rayon
a_min_circle = 1 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 2 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 5 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 7 et 9 (Grand cercle de rayon 9 et petit cercle de rayon 7)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 1 et 2 (Grand cercle de rayon 2 et petit cercle de rayon 1)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V3.1.0_16_11_0_2020-08-28 02:04:17.027292

# %% [markdown]
# ## Version 3.2.0

# %%
version = "3.2.0"

#Normal data
n_min_circle = 7 #Rayon
n_max_circle = 9 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0  #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 2 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 2 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 7 et 9 (Grand cercle de rayon 9 et petit cercle de rayon 7)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V3.2.0_16_11_0_2020-08-28 02:21:15.275172

# %% [markdown]
# ## Version 3.3.0

# %%
version = "3.3.0"

#Normal data
n_min_circle = 8 #Rayon
n_max_circle = 9 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 3 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 8 et 9 (Grand cercle de rayon 9 et petit cercle de rayon 8)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V3.3.0_16_11_0_2020-08-28 02:24:40.613134

# %% [markdown]
# ## Version 3.4.0

# %%
version = "3.4.0"

#Normal data
n_min_circle = 8 #Rayon
n_max_circle = 10 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 2 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 3 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 8 et 10 (Grand cercle de rayon 10 et petit cercle de rayon 8)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V3.4.0_16_11_0_2020-08-28 02:29:14.896986

# %% [markdown]
# ## Version 4.0.0

# %%
version = "4.0.0"

#Normal data
n_min_circle = 9 #Rayon
n_max_circle = 10 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 4 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -12
max_value = 12
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 4 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 1500,
#  - distance euclidienne entre 9 et 10 (Grand cercle de rayon 10 et petit cercle de rayon 9)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -12 et 12,
#  - y entre -12 et 12,
#  - taille = 15,
#  - distance euclidienne entre 4 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 4)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V4.0.0_16_11_0_2020-08-28 02:34:30.784786

# %% [markdown]
# ## Version 4.2.0

# %%
version = "4.2.0"

#Normal data
n_min_circle = 9 #Rayon
n_max_circle = 10 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 16
y_lim = 11
z_lim = 0.0

min_value = -15
max_value = 15
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 4 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -15 et 15,
#  - y entre -15 et 15,
#  - taille = 1500,
#  - distance euclidienne entre 9 et 10 (Grand cercle de rayon 10 et petit cercle de rayon 9)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -15 et 15,
#  - y entre -15 et 15,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V4.2.0_16_11_0_2020-08-28 02:45:59.986385

# %% [markdown]
# ## Version 4.3.0

# %%
version = "4.3.0"

#Normal data
n_min_circle = 15 #Rayon
n_max_circle = 16 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 28
y_lim = 20
z_lim = 0.0

min_value = -20
max_value = 20
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 10 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 1500,
#  - distance euclidienne entre 15 et 16 (Grand cercle de rayon 16 et petit cercle de rayon 15)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...
# Output()
# ...

# %% [markdown]
# ## Version 4.3.1

# %%
version = "4.3.1"

#Normal data
n_min_circle = 17 #Rayon
n_max_circle = 18 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 28
y_lim = 20
z_lim = 0.0

min_value = -20
max_value = 20
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 1 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 12 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 1500,
#  - distance euclidienne entre 17 et 18 (Grand cercle de rayon 18 et petit cercle de rayon 17)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V4.3.1_28_20_0_2020-08-28 02:59:49.376502

# %% [markdown]
# ## Version 4.3.2

# %%
version = "4.3.2"

#Normal data
n_min_circle = 17 #Rayon
n_max_circle = 19 #Rayon
n_distribution="uniform"

#Abnormal data
a_max_circle = 5 #Rayon
a_min_circle = 0.0 #Rayon
a_distribution="uniform"

x_lim = 28
y_lim = 20
z_lim = 0.0

min_value = -20
max_value = 20
mu = 0.0
sigma = 0.0

data_gene.dataset_generator(n_size=n_size, n_small_circle=n_min_circle,n_big_circle=n_max_circle, 
                            n_distribution=n_distribution, 
                            a_size=size_a, a_small_circle=a_min_circle,a_big_circle=a_max_circle, 
                            a_distribution=a_distribution,
                            x_lim=x_lim, y_lim=y_lim,z_lim=z_lim, min_value=min_value, max_value=max_value,
                            mu=mu, sigma=sigma, version=version,n_dimension = n_dimension)
# Out:
# Jeu de données à 2 dimensions constitué de 1500 données normales et de 15 données anormales.
#  Les données anormales se retrouvent au centre d'un grand cercle formé par les données normales.
#  Les données normales sont à une distance maximale de 2 les unes des autres.
#  Les données anormales se trouve à une distance minimale de 12 des données normales.
#  Données normales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 1500,
#  - distance euclidienne entre 17 et 19 (Grand cercle de rayon 19 et petit cercle de rayon 17)
#  Données anormales :
#  - Données aléatoires uniform
#  - x entre -20 et 20,
#  - y entre -20 et 20,
#  - taille = 15,
#  - distance euclidienne entre 0.0 et 5 (Grand cercle de rayon 5 et petit cercle de rayon 0.0)
# ...
# Output()
# Dataset well saved in File name = Synthetics_2D/synthetic_2D_dataset_V4.3.2_28_20_0_2020-09-02 10:41:40.241642
