# %% [markdown]
# # What is IForest behavior according to the dataset dimension size?

# %% [markdown]
# ## Test with 1 dimension dataset

# %%
import sys
sys.path.append('../')
from datasets import datasets as datat
from IForest_DODiMDS import iforest_D as IFD
from metrics import performances
from metrics import visualization
visu = visualization.visualization()

import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score, recall_score
from imblearn.metrics import specificity_score
from imblearn.metrics import sensitivity_score
from imblearn.metrics import specificity_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve

import matplotlib.cm as cm
from mpl_toolkits import mplot3d

# %% [markdown]
# ## Generals settings

# %%
max_samples = 256
n_trees = 100
threshold = 0.6

# %% [markdown]
# ## Chargement du jeu de données

# %%
data_path = datat.path_HTTP_IForestASD
dts = datat.reals_datasets(path_top="../")
X_full_brut, y_full_transform, full_dataset = dts.HTTP_IForestASD()
print("X_full_brut")
print(X_full_brut.describe())
print("y_full_transform")
print(y_full_transform.describe())
print("full_dataset")
print(full_dataset.describe())
print("***************************************************************************************")
X_normals_brut, y_normals_transform, full_normals_dataset = datat.only_normals(data_path, '\'Anomaly\'')
print("X_normals_brut")
print(X_normals_brut.describe())
print("y_normals_transform")
print(y_normals_transform.describe())
print("full_normals_dataset")
print(full_normals_dataset.describe())
print("***************************************************************************************")
X_abnormals_brut, y_abnormals_transform, full_abnormals_dataset = datat.only_abnormals(data_path, '\'Anomaly\'')
print("X_abnormals_brut")
print(X_abnormals_brut.describe())
print("y_abnormals_transform")
print(y_abnormals_transform.describe())
print("full_abnormals_dataset")
print(full_abnormals_dataset.describe())
print("% of anomaly in the dataset")
print(str(len(full_abnormals_dataset)*100/len(full_dataset))+"%")
# Out:
# Columns number = 4
# X_full_brut
#              0       1       2
# count   567498  567498  567498
# unique     580     911   27100
# top          0     209    2698
# freq    433416    4428    3109
# y_full_transform
#               0
# count  567498.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# full_dataset
#              0       1       2         3
# count   567498  567498  567498    567498
# unique     580     911   27100         3
# top          0     209    2698  'Normal'
# freq    433416    4428    3109    565286
# ***************************************************************************************
# Columns number = 4
# X_normals_brut
#              0       1       2
# count   565287  565287  565287
# unique     580     867   27100
# top          0     209    2698
# freq    431248    4428    3109
# y_normals_transform
#               0
# count  565287.0
# mean        1.0
# std         0.0
# ...

# %%
data_path = datat.path_ForestCover_IForestASD
dts = datat.reals_datasets(path_top="../")
X_full_brut, y_full_transform, full_dataset = dts.ForestCover_IForestASD()
print("X_full_brut")
print(X_full_brut.describe())
print("y_full_transform")
print(y_full_transform.describe())
print("full_dataset")
print(full_dataset.describe())
print("***************************************************************************************")
X_normals_brut, y_normals_transform, full_normals_dataset = datat.only_normals(data_path, '\'Anomaly\'')
print("X_normals_brut")
print(X_normals_brut.describe())
print("y_normals_transform")
print(y_normals_transform.describe())
print("full_normals_dataset")
print(full_normals_dataset.describe())
print("***************************************************************************************")
X_abnormals_brut, y_abnormals_transform, full_abnormals_dataset = datat.only_abnormals(data_path, '\'Anomaly\'')
print("X_abnormals_brut")
print(X_abnormals_brut.describe())
print("y_abnormals_transform")
print(y_abnormals_transform.describe())
print("full_abnormals_dataset")
print(full_abnormals_dataset.describe())
print("% of anomaly in the dataset")
print(str(len(full_abnormals_dataset)*100/len(full_dataset))+"%")
# Out:
# Columns number = 11
# X_full_brut
#              0       1       2       3       4       5       6       7  \
# count   286049  286049  286049  286049  286049  286049  286049  286049
# unique    2604     723     124     926    1055   10928     364     300
# top       2952      45      12      30       0     150     228     228
# freq       699    2053   12782   10235   10996     483    4239    4918
#
#              8       9
# count   286049  286049
# unique     503    9239
# top        136     618
# freq      2560     522
# y_full_transform
#               0
# count  286049.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# full_dataset
#             0       1       2       3       4       5       6       7   \
# count   286049  286049  286049  286049  286049  286049  286049  286049
# unique    2604     723     124     926    1055   10928     364     300
# ...

# %%
data_path = datat.path_Shuttle_IForestASD
dts = datat.reals_datasets(path_top="../")
X_full_brut, y_full_transform, full_dataset = dts.Shuttle_IForestASD()
print("X_full_brut")
print(X_full_brut.describe())
print("y_full_transform")
print(y_full_transform.describe())
print("full_dataset")
print(full_dataset.describe())
print("***************************************************************************************")
X_normals_brut, y_normals_transform, full_normals_dataset = datat.only_normals(data_path, '\'Anomaly\'')
print("X_normals_brut")
print(X_normals_brut.describe())
print("y_normals_transform")
print(y_normals_transform.describe())
print("full_normals_dataset")
print(full_normals_dataset.describe())
print("***************************************************************************************")
X_abnormals_brut, y_abnormals_transform, full_abnormals_dataset = datat.only_abnormals(data_path, '\'Anomaly\'')
print("X_abnormals_brut")
print(X_abnormals_brut.describe())
print("y_abnormals_transform")
print(y_abnormals_transform.describe())
print("full_abnormals_dataset")
print(full_abnormals_dataset.describe())
print("% of anomaly in the dataset")
print(str(len(full_abnormals_dataset)*100/len(full_dataset))+"%")
# Out:
# Columns number = 10
# X_full_brut
#             0      1      2      3      4      5      6      7      8
# count   49098  49098  49098  49098  49098  49098  49098  49098  49098
# unique     77    203     49    127     55    282     87    119     76
# top        37      0     86      0     46      0     40     37      0
# freq    13308  29001   4389  32106   5886  16293   3601   2708  20134
# y_full_transform
#              0
# count  49098.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# full_dataset
#             0      1      2      3      4      5      6      7      8  \
# count   49098  49098  49098  49098  49098  49098  49098  49098  49098
# unique     77    203     49    127     55    282     87    119     76
# top        37      0     86      0     46      0     40     37      0
# freq    13308  29001   4389  32106   5886  16293   3601   2708  20134
#
#                9
# count      49098
# ...

# %%
data_path = datat.path_SMTP_IForestASD
dts = datat.reals_datasets(path_top="../")
X_full_brut, y_full_transform, full_dataset = dts.SMTP_IForestASD()
print("X_full_brut")
print(X_full_brut.describe())
print("y_full_transform")
print(y_full_transform.describe())
print("full_dataset")
print(full_dataset.describe())
print("***************************************************************************************")
X_normals_brut, y_normals_transform, full_normals_dataset = datat.only_normals(data_path, '\'Anomaly\'')
print("X_normals_brut")
print(X_normals_brut.describe())
print("y_normals_transform")
print(y_normals_transform.describe())
print("full_normals_dataset")
print(full_normals_dataset.describe())
print("***************************************************************************************")
X_abnormals_brut, y_abnormals_transform, full_abnormals_dataset = datat.only_abnormals(data_path, '\'Anomaly\'')
print("X_abnormals_brut")
print(X_abnormals_brut.describe())
print("y_abnormals_transform")
print(y_abnormals_transform.describe())
print("full_abnormals_dataset")
print(full_abnormals_dataset.describe())
print("% of anomaly in the dataset")
print(str(len(full_abnormals_dataset)*100/len(full_dataset))+"%")
# Out:
# Columns number = 4
# X_full_brut
#             0      1      2
# count   95157  95157  95157
# unique    239   6312    603
# top         0    801    330
# freq    47021    116   8042
# y_full_transform
#              0
# count  95157.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# full_dataset
#             0      1      2         3
# count   95157  95157  95157     95157
# unique    239   6312    603         3
# top         0    801    330  'Normal'
# freq    47021    116   8042     95126
# ***************************************************************************************
# Columns number = 4
# X_normals_brut
#             0      1      2
# count   95127  95127  95127
# unique    239   6309    592
# top         0    801    330
# freq    47008    116   8042
# y_normals_transform
#              0
# count  95127.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# ...
